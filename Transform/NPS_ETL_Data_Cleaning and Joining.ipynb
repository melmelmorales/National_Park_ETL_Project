# %% [markdown]
# ### Step 1: Import Dependencies required to perform data transformation steps

# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Step 2: Read in csv files containing data extractions from various API calls to the National Park Service webpage.

# %%
NPS_Amenities_df = pd.read_csv("../Extract/NPS Amenities Info/NPS_Project_Extracted_Data/nps_amenities_data.csv")
NPS_Amenities_df.head(5)
# Out:
#                              amenity_id      amenity_name  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 1  4E4D076A-6866-46C8-A28B-A129E2B8F3DB  Accessible Rooms
# 2  04D29064-B9A1-4031-AD0E-98E31EF69604  Accessible Sites
# 3  0E2B9B01-9AC3-4AAF-A801-8027314BE863    Airboat Launch
# 4  B509969B-F06A-4DCC-BBB3-134964D896E2      Amphitheater
#
#                       amenity_category
# 0  Convenience, Souvenirs and Supplies
# 1                        Accessibility
# 2                        Accessibility
# 3                              Boating
# 4             Interpretive, Recreation

# %%
NPS_Amenities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   amenity_id        50 non-null     object
#  1   amenity_name      50 non-null     object
#  2   amenity_category  50 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
NPS_AmenitiesByPlace_df = pd.read_csv("../Extract/NPS Amenities Info/NPS_Project_Extracted_Data/nps_amen_place_data.csv")
NPS_AmenitiesByPlace_df.head(5)
# Out:
#                              amenity_id      amenity_name park_code  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      badl
# 1  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      bibe
# 2  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      brca
# 3  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      cabr
# 4  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      deva
#
#                     park_name park_states   park_designation  \
# 0      Badlands National Park          SD      National Park
# 1      Big Bend National Park          TX      National Park
# 2  Bryce Canyon National Park          UT      National Park
# 3  Cabrillo National Monument          CA  National Monument
# 4  Death Valley National Park       CA,NV      National Park
#
#                    park_url
# 0  http://www.nps.gov/badl/
# 1  http://www.nps.gov/bibe/
# 2  http://www.nps.gov/brca/
# 3  http://www.nps.gov/cabr/
# 4  http://www.nps.gov/deva/

# %%
NPS_AmenitiesByPlace_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2581 entries, 0 to 2580
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   amenity_id        2581 non-null   object
#  1   amenity_name      2581 non-null   object
#  2   park_code         2581 non-null   object
#  3   park_name         2581 non-null   object
#  4   park_states       2581 non-null   object
#  5   park_designation  2453 non-null   object
#  6   park_url          2575 non-null   object
# dtypes: object(7)
# memory usage: 141.3+ KB

# %%
NPS_Parks_df = pd.read_csv("../Extract/NPS Amenities Info/NPS_Project_Extracted_Data/nps_parks_data.csv")
NPS_Parks_df.head(5)
# Out:
#                                 park_id                            park_url  \
# 0  77E0D7F0-1942-494A-ACE2-9004D2BDC59E  https://www.nps.gov/abli/index.htm
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 2  E4C7784E-66A0-4D44-87D0-3E072F5FEF43  https://www.nps.gov/adam/index.htm
# 3  1A47416F-DAA3-4137-9F30-14AF86B4E547  https://www.nps.gov/afam/index.htm
# 4  E6E1D22A-7A89-47F8-813C-B611059A8CF9  https://www.nps.gov/afbg/index.htm
#
#                                            park_name park_code  park_latitude  \
# 0  Abraham Lincoln Birthplace National Historical...      abli      37.585866
# 1                               Acadia National Park      acad      44.409286
# 2                     Adams National Historical Park      adam      42.255396
# 3                African American Civil War Memorial      afam      38.916600
# 4            African Burial Ground National Monument      afbg      40.714527
#
#    park_longitude          park_designation
# 0      -85.673305  National Historical Park
# 1      -68.247501             National Park
# 2      -71.011604  National Historical Park
# 3      -77.026000                       NaN
# 4      -74.004474         National Monument

# %%
NPS_Parks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   park_id           50 non-null     object
#  1   park_url          50 non-null     object
#  2   park_name         50 non-null     object
#  3   park_code         50 non-null     object
#  4   park_latitude     49 non-null     float64
#  5   park_longitude    49 non-null     float64
#  6   park_designation  46 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 2.9+ KB

# %%
NPS_Activities_df = pd.read_csv("../Extract/NPS_Activities_Fees/NPS_Project_Extracted_Data/activities.csv")
NPS_Activities_df.head(5)
# Out:
#                             activity_id     activity_name
# 0  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 1  13A57703-BB1A-41A2-94B8-53B692EB7238         Astronomy
# 2  5F723BAD-7359-48FC-98FA-631592256E35      Auto and ATV
# 3  7CE6E935-F839-4FEC-A63E-052B1DEF39D2            Biking
# 4  071BA73C-1D3C-46D4-A53C-00D5602F7F0E           Boating

# %%
NPS_Activities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   activity_id    40 non-null     object
#  1   activity_name  40 non-null     object
# dtypes: object(2)
# memory usage: 768.0+ bytes

# %%
NPS_ActivitiesByPark_df = pd.read_csv("../Extract/NPS_Activities_Fees/NPS_Project_Extracted_Data/activities_parks.csv")
NPS_ActivitiesByPark_df.head(5)
# Out:
#                             activity_id     activity_name    designation  \
# 0  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 1  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 2  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 3  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 4  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
#
#                         fullName             name parkCode states  \
# 0           Acadia National Park           Acadia     acad     ME
# 1           Arches National Park           Arches     arch     UT
# 2     Capitol Reef National Park     Capitol Reef     care     UT
# 3  Cuyahoga Valley National Park  Cuyahoga Valley     cuva     OH
# 4          Glacier National Park          Glacier     glac     MT
#
#                                   url
# 0  https://www.nps.gov/acad/index.htm
# 1  https://www.nps.gov/arch/index.htm
# 2  https://www.nps.gov/care/index.htm
# 3  https://www.nps.gov/cuva/index.htm
# 4  https://www.nps.gov/glac/index.htm

# %%
NPS_ActivitiesByPark_df.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   activity_id    769 non-null    object
#  1   activity_name  769 non-null    object
#  2   designation    769 non-null    object
#  3   fullName       769 non-null    object
#  4   name           769 non-null    object
#  5   parkCode       769 non-null    object
#  6   states         769 non-null    object
#  7   url            769 non-null    object
# dtypes: object(8)
# memory usage: 48.2+ KB

# %%
NPS_EntranceFees_df = pd.read_csv("../Extract/NPS_Activities_Fees/NPS_Project_Extracted_Data/feespasses.csv")
NPS_EntranceFees_df.head(5)
# Out:
#   parkCode  totalFees  averageFees  totalPasses  averagePasses  isFeeFreePark  \
# 0     acad       91.0    13.000000         70.0           70.0          False
# 1     arch       72.0    18.000000         55.0           55.0          False
# 2     badl      355.0    50.714286         55.0           55.0          False
# 3     bibe      425.0    60.714286         55.0           55.0          False
# 4     bisc        0.0     0.000000          0.0            0.0           True
#
#                              entrancePassDescription  \
# 0  A park entrance pass is required year-round. A...
# 1                                                NaN
# 2                                                NaN
# 3  Big Bend National Park Annual Pass: $55 Covers...
# 4                                                NaN
#
#                               entranceFeeDescription  \
# 0  A park entrance pass is required year-round at...
# 1                                                NaN
# 2  Badlands National Park charges an entrance fee...
# 3  All vehicles entering Big Bend National Park a...
# 4                                                NaN
#
#                                        feesAtWorkUrl
# 0    https://www.nps.gov/acad/planyourvisit/fees.htm
# 1  https://www.nps.gov/arch/learn/management/your...
# 2                                                NaN
# 3  https://www.nps.gov/bibe/learn/management/your...
# 4                                                NaN

# %%
NPS_EntranceFees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   parkCode                 6 non-null      object
#  1   totalFees                6 non-null      float64
#  2   averageFees              6 non-null      float64
#  3   totalPasses              6 non-null      float64
#  4   averagePasses            6 non-null      float64
#  5   isFeeFreePark            6 non-null      bool
#  6   entrancePassDescription  2 non-null      object
#  7   entranceFeeDescription   3 non-null      object
#  8   feesAtWorkUrl            3 non-null      object
# dtypes: bool(1), float64(4), object(4)
# memory usage: 518.0+ bytes

# %%
# Additional line to add Melissa's output file(s) once available
# NPS_GeoLocation_df = pd.read_csv("Extract/NPS_Park_Boundaries/NPS_Project_Extracted_Data/filename.csv")

# %% [markdown]
# ### Step 3: Edit data to create a single, comprehensive, cleaned dataset for use in analysis

# %%
# Merge the two ammenity DataFrames together based on the amenity information they share
Amenity_df = pd.merge(NPS_Amenities_df, NPS_AmenitiesByPlace_df, on=["amenity_id", "amenity_name"])
Amenity_df.head(5)
# Out:
#                              amenity_id      amenity_name  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 1  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 2  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 3  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 4  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
#
#                       amenity_category park_code                   park_name  \
# 0  Convenience, Souvenirs and Supplies      badl      Badlands National Park
# 1  Convenience, Souvenirs and Supplies      bibe      Big Bend National Park
# 2  Convenience, Souvenirs and Supplies      brca  Bryce Canyon National Park
# 3  Convenience, Souvenirs and Supplies      cabr  Cabrillo National Monument
# 4  Convenience, Souvenirs and Supplies      deva  Death Valley National Park
#
#   park_states   park_designation                  park_url
# 0          SD      National Park  http://www.nps.gov/badl/
# 1          TX      National Park  http://www.nps.gov/bibe/
# 2          UT      National Park  http://www.nps.gov/brca/
# 3          CA  National Monument  http://www.nps.gov/cabr/
# 4       CA,NV      National Park  http://www.nps.gov/deva/

# %%
# Merge the two activities DataFrames together based on the activity information they share
Activity_df = pd.merge(NPS_Activities_df, NPS_ActivitiesByPark_df, on=["activity_id", "activity_name"])
Activity_df.head(5)
# Out:
#                             activity_id     activity_name    designation  \
# 0  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 1  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 2  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 3  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 4  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
#
#                         fullName             name parkCode states  \
# 0           Acadia National Park           Acadia     acad     ME
# 1           Arches National Park           Arches     arch     UT
# 2     Capitol Reef National Park     Capitol Reef     care     UT
# 3  Cuyahoga Valley National Park  Cuyahoga Valley     cuva     OH
# 4          Glacier National Park          Glacier     glac     MT
#
#                                   url
# 0  https://www.nps.gov/acad/index.htm
# 1  https://www.nps.gov/arch/index.htm
# 2  https://www.nps.gov/care/index.htm
# 3  https://www.nps.gov/cuva/index.htm
# 4  https://www.nps.gov/glac/index.htm

# %%
# Rename column headers to prepare for merge
Activity_df.rename(columns={"fullName": "park_name", "parkCode": "park_code"}, inplace=True)
Activity_df.head(5)
# Out:
#                             activity_id     activity_name    designation  \
# 0  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 1  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 2  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 3  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 4  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
#
#                        park_name             name park_code states  \
# 0           Acadia National Park           Acadia      acad     ME
# 1           Arches National Park           Arches      arch     UT
# 2     Capitol Reef National Park     Capitol Reef      care     UT
# 3  Cuyahoga Valley National Park  Cuyahoga Valley      cuva     OH
# 4          Glacier National Park          Glacier      glac     MT
#
#                                   url
# 0  https://www.nps.gov/acad/index.htm
# 1  https://www.nps.gov/arch/index.htm
# 2  https://www.nps.gov/care/index.htm
# 3  https://www.nps.gov/cuva/index.htm
# 4  https://www.nps.gov/glac/index.htm

# %%
# Merge the two activities DataFrames together based on the park location information they share
Amen_Act_df = pd.merge(Amenity_df, Activity_df, on=["park_name", "park_code"])
Amen_Act_df.head(5)
# Out:
#                              amenity_id      amenity_name  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 1  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 2  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 3  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 4  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
#
#                       amenity_category park_code               park_name  \
# 0  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 1  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 2  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 3  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 4  Convenience, Souvenirs and Supplies      badl  Badlands National Park
#
#   park_states park_designation                  park_url  \
# 0          SD    National Park  http://www.nps.gov/badl/
# 1          SD    National Park  http://www.nps.gov/badl/
# 2          SD    National Park  http://www.nps.gov/badl/
# 3          SD    National Park  http://www.nps.gov/badl/
# 4          SD    National Park  http://www.nps.gov/badl/
#
#                             activity_id    activity_name    designation  \
# 0  13A57703-BB1A-41A2-94B8-53B692EB7238        Astronomy  National Park
# 1  5F723BAD-7359-48FC-98FA-631592256E35     Auto and ATV  National Park
# 2  7CE6E935-F839-4FEC-A63E-052B1DEF39D2           Biking  National Park
# 3  A59947B7-3376-49B4-AD02-C0423E08C5F7          Camping  National Park
# 4  C11D3746-5063-4BD0-B245-7178D1AD866C  Compass and GPS  National Park
#
#        name states                                 url
# 0  Badlands     SD  https://www.nps.gov/badl/index.htm
# 1  Badlands     SD  https://www.nps.gov/badl/index.htm
# 2  Badlands     SD  https://www.nps.gov/badl/index.htm
# 3  Badlands     SD  https://www.nps.gov/badl/index.htm
# 4  Badlands     SD  https://www.nps.gov/badl/index.htm

# %%
Amen_Act_Per_Park_df = pd.merge(Amen_Act_df, NPS_Parks_df, on=["park_name", "park_code"])
Amen_Act_Per_Park_df.head(5)
# Out:
#                              amenity_id      amenity_name  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 1  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 2  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 3  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 4  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
#
#                       amenity_category park_code               park_name  \
# 0  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 1  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 2  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 3  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 4  Convenience, Souvenirs and Supplies      badl  Badlands National Park
#
#   park_states park_designation_x                park_url_x  \
# 0          SD      National Park  http://www.nps.gov/badl/
# 1          SD      National Park  http://www.nps.gov/badl/
# 2          SD      National Park  http://www.nps.gov/badl/
# 3          SD      National Park  http://www.nps.gov/badl/
# 4          SD      National Park  http://www.nps.gov/badl/
#
#                             activity_id    activity_name    designation  \
# 0  13A57703-BB1A-41A2-94B8-53B692EB7238        Astronomy  National Park
# 1  5F723BAD-7359-48FC-98FA-631592256E35     Auto and ATV  National Park
# 2  7CE6E935-F839-4FEC-A63E-052B1DEF39D2           Biking  National Park
# 3  A59947B7-3376-49B4-AD02-C0423E08C5F7          Camping  National Park
# 4  C11D3746-5063-4BD0-B245-7178D1AD866C  Compass and GPS  National Park
#
#        name states                                 url  \
# 0  Badlands     SD  https://www.nps.gov/badl/index.htm
# 1  Badlands     SD  https://www.nps.gov/badl/index.htm
# 2  Badlands     SD  https://www.nps.gov/badl/index.htm
# 3  Badlands     SD  https://www.nps.gov/badl/index.htm
# 4  Badlands     SD  https://www.nps.gov/badl/index.htm
#
#                                 park_id                          park_url_y  \
# 0  B170CCF7-7AB9-48FF-950E-31815FD4DBB2  https://www.nps.gov/badl/index.htm
# 1  B170CCF7-7AB9-48FF-950E-31815FD4DBB2  https://www.nps.gov/badl/index.htm
# 2  B170CCF7-7AB9-48FF-950E-31815FD4DBB2  https://www.nps.gov/badl/index.htm
# 3  B170CCF7-7AB9-48FF-950E-31815FD4DBB2  https://www.nps.gov/badl/index.htm
# 4  B170CCF7-7AB9-48FF-950E-31815FD4DBB2  https://www.nps.gov/badl/index.htm
#
#    park_latitude  park_longitude park_designation_y
# 0      43.685848     -102.482942      National Park
# 1      43.685848     -102.482942      National Park
# 2      43.685848     -102.482942      National Park
# 3      43.685848     -102.482942      National Park
# 4      43.685848     -102.482942      National Park

# %%
# Rename column headers to prepare for merge
NPS_EntranceFees_df.rename(columns={"parkCode": "park_code"}, inplace=True)
NPS_EntranceFees_df.head(5)
# Out:
#   park_code  totalFees  averageFees  totalPasses  averagePasses  \
# 0      acad       91.0    13.000000         70.0           70.0
# 1      arch       72.0    18.000000         55.0           55.0
# 2      badl      355.0    50.714286         55.0           55.0
# 3      bibe      425.0    60.714286         55.0           55.0
# 4      bisc        0.0     0.000000          0.0            0.0
#
#    isFeeFreePark                            entrancePassDescription  \
# 0          False  A park entrance pass is required year-round. A...
# 1          False                                                NaN
# 2          False                                                NaN
# 3          False  Big Bend National Park Annual Pass: $55 Covers...
# 4           True                                                NaN
#
#                               entranceFeeDescription  \
# 0  A park entrance pass is required year-round at...
# 1                                                NaN
# 2  Badlands National Park charges an entrance fee...
# 3  All vehicles entering Big Bend National Park a...
# 4                                                NaN
#
#                                        feesAtWorkUrl
# 0    https://www.nps.gov/acad/planyourvisit/fees.htm
# 1  https://www.nps.gov/arch/learn/management/your...
# 2                                                NaN
# 3  https://www.nps.gov/bibe/learn/management/your...
# 4                                                NaN

# %%
Fee_Amen_Act_Loc_df = pd.merge(Amen_Act_Per_Park_df, NPS_EntranceFees_df, on=["park_code"])
Fee_Amen_Act_Loc_df.head(5)
# Out:
#                              amenity_id      amenity_name  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 1  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 2  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 3  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 4  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
#
#                       amenity_category park_code               park_name  \
# 0  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 1  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 2  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 3  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 4  Convenience, Souvenirs and Supplies      badl  Badlands National Park
#
#   park_states park_designation_x                park_url_x  \
# 0          SD      National Park  http://www.nps.gov/badl/
# 1          SD      National Park  http://www.nps.gov/badl/
# 2          SD      National Park  http://www.nps.gov/badl/
# 3          SD      National Park  http://www.nps.gov/badl/
# 4          SD      National Park  http://www.nps.gov/badl/
#
#                             activity_id    activity_name  ... park_longitude  \
# 0  13A57703-BB1A-41A2-94B8-53B692EB7238        Astronomy  ...    -102.482942
# 1  5F723BAD-7359-48FC-98FA-631592256E35     Auto and ATV  ...    -102.482942
# 2  7CE6E935-F839-4FEC-A63E-052B1DEF39D2           Biking  ...    -102.482942
# 3  A59947B7-3376-49B4-AD02-C0423E08C5F7          Camping  ...    -102.482942
# 4  C11D3746-5063-4BD0-B245-7178D1AD866C  Compass and GPS  ...    -102.482942
#
#   park_designation_y totalFees averageFees totalPasses averagePasses  \
# 0      National Park     355.0   50.714286        55.0          55.0
# 1      National Park     355.0   50.714286        55.0          55.0
# 2      National Park     355.0   50.714286        55.0          55.0
# 3      National Park     355.0   50.714286        55.0          55.0
# 4      National Park     355.0   50.714286        55.0          55.0
#
#    isFeeFreePark  entrancePassDescription  \
# 0          False                      NaN
# 1          False                      NaN
# 2          False                      NaN
# 3          False                      NaN
# 4          False                      NaN
#
#                               entranceFeeDescription  feesAtWorkUrl
# 0  Badlands National Park charges an entrance fee...            NaN
# 1  Badlands National Park charges an entrance fee...            NaN
# 2  Badlands National Park charges an entrance fee...            NaN
# 3  Badlands National Park charges an entrance fee...            NaN
# 4  Badlands National Park charges an entrance fee...            NaN
#
# [5 rows x 27 columns]

# %%
Fee_Amen_Act_Loc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   amenity_id               680 non-null    object
#  1   amenity_name             680 non-null    object
#  2   amenity_category         680 non-null    object
#  3   park_code                680 non-null    object
#  4   park_name                680 non-null    object
#  5   park_states              680 non-null    object
#  6   park_designation_x       680 non-null    object
#  7   park_url_x               680 non-null    object
#  8   activity_id              680 non-null    object
#  9   activity_name            680 non-null    object
#  10  designation              680 non-null    object
#  11  name                     680 non-null    object
#  12  states                   680 non-null    object
#  13  url                      680 non-null    object
#  14  park_id                  680 non-null    object
#  15  park_url_y               680 non-null    object
#  16  park_latitude            680 non-null    float64
#  17  park_longitude           680 non-null    float64
#  18  park_designation_y       680 non-null    object
#  19  totalFees                680 non-null    float64
#  20  averageFees              680 non-null    float64
#  21  totalPasses              680 non-null    float64
#  22  averagePasses            680 non-null    float64
#  23  isFeeFreePark            680 non-null    bool
#  24  entrancePassDescription  540 non-null    object
#  25  entranceFeeDescription   660 non-null    object
#  26  feesAtWorkUrl            551 non-null    object
# dtypes: bool(1), float64(6), object(20)
# memory usage: 138.9+ KB

# %%
# Only keep rows that correspond to a National Park
NPS_dataset_df = Fee_Amen_Act_Loc_df[(Fee_Amen_Act_Loc_df["park_designation_x"] == "National Park")]
NPS_dataset_df.head(5)
# Out:
#                              amenity_id      amenity_name  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 1  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 2  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 3  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
# 4  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine
#
#                       amenity_category park_code               park_name  \
# 0  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 1  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 2  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 3  Convenience, Souvenirs and Supplies      badl  Badlands National Park
# 4  Convenience, Souvenirs and Supplies      badl  Badlands National Park
#
#   park_states park_designation_x                park_url_x  \
# 0          SD      National Park  http://www.nps.gov/badl/
# 1          SD      National Park  http://www.nps.gov/badl/
# 2          SD      National Park  http://www.nps.gov/badl/
# 3          SD      National Park  http://www.nps.gov/badl/
# 4          SD      National Park  http://www.nps.gov/badl/
#
#                             activity_id    activity_name  ... park_longitude  \
# 0  13A57703-BB1A-41A2-94B8-53B692EB7238        Astronomy  ...    -102.482942
# 1  5F723BAD-7359-48FC-98FA-631592256E35     Auto and ATV  ...    -102.482942
# 2  7CE6E935-F839-4FEC-A63E-052B1DEF39D2           Biking  ...    -102.482942
# 3  A59947B7-3376-49B4-AD02-C0423E08C5F7          Camping  ...    -102.482942
# 4  C11D3746-5063-4BD0-B245-7178D1AD866C  Compass and GPS  ...    -102.482942
#
#   park_designation_y totalFees averageFees totalPasses averagePasses  \
# 0      National Park     355.0   50.714286        55.0          55.0
# 1      National Park     355.0   50.714286        55.0          55.0
# 2      National Park     355.0   50.714286        55.0          55.0
# 3      National Park     355.0   50.714286        55.0          55.0
# 4      National Park     355.0   50.714286        55.0          55.0
#
#    isFeeFreePark  entrancePassDescription  \
# 0          False                      NaN
# 1          False                      NaN
# 2          False                      NaN
# 3          False                      NaN
# 4          False                      NaN
#
#                               entranceFeeDescription  feesAtWorkUrl
# 0  Badlands National Park charges an entrance fee...            NaN
# 1  Badlands National Park charges an entrance fee...            NaN
# 2  Badlands National Park charges an entrance fee...            NaN
# 3  Badlands National Park charges an entrance fee...            NaN
# 4  Badlands National Park charges an entrance fee...            NaN
#
# [5 rows x 27 columns]

# %%
# View all available columns
print(NPS_dataset_df.columns)
# Out:
# Index(['amenity_id', 'amenity_name', 'amenity_category', 'park_code',
#        'park_name', 'park_states', 'park_designation_x', 'park_url_x',
#        'activity_id', 'activity_name', 'designation', 'name', 'states', 'url',
#        'park_id', 'park_url_y', 'park_latitude', 'park_longitude',
#        'park_designation_y', 'totalFees', 'averageFees', 'totalPasses',
#        'averagePasses', 'isFeeFreePark', 'entrancePassDescription',
#        'entranceFeeDescription', 'feesAtWorkUrl'],
#       dtype='object')

# %%
# Create a DataFrame called NPS_Cleaned_df with only columns useful for downstream data analysis

# Remove fields not useful to data analysis from the dataset
NPS_Cleaned_df = NPS_dataset_df[['amenity_name', 'park_code', 'park_name', 'park_states', 'park_designation_x', 
    'park_url_x', 'activity_name', 'park_latitude', 'park_longitude', 'totalFees', 
    'isFeeFreePark']]
    
# Rename the columns 
NPS_Cleaned_df = NPS_Cleaned_df.rename(columns={
    'park_designation_x': 'Park Designation',
    'park_code': 'Park Code',
    'park_name': 'Park Name',
    'park_states': 'Present in States',
    'isFeeFreePark': 'Free Entrance',
    'totalFees': 'Entrance Fee',
    'park_url_x': 'Park Website',
    'activity_name': 'Activity Option',
    'amenity_name': 'Available Amenity',
    'park_latitude': 'Park Latitude',
    'park_longitude': 'Park Longitude'
})

# Reorder the columns
NPS_Cleaned_df = NPS_Cleaned_df[['Park Designation', 'Park Code', 'Park Name', 'Present in States', 'Free Entrance',
                                 'Entrance Fee', 'Park Website', 'Activity Option', 'Available Amenity', 'Park Latitude', 'Park Longitude']]

# Format the Entrance Fee column
NPS_Cleaned_df["Entrance Fees"] = NPS_Cleaned_df["Entrance Fee"].map("${:,.2f}".format)

# Display the DataFrame
NPS_Cleaned_df.head(5)
# Out:
#   Park Designation Park Code               Park Name Present in States  \
# 0    National Park      badl  Badlands National Park                SD
# 1    National Park      badl  Badlands National Park                SD
# 2    National Park      badl  Badlands National Park                SD
# 3    National Park      badl  Badlands National Park                SD
# 4    National Park      badl  Badlands National Park                SD
#
#    Free Entrance  Entrance Fee              Park Website  Activity Option  \
# 0          False         355.0  http://www.nps.gov/badl/        Astronomy
# 1          False         355.0  http://www.nps.gov/badl/     Auto and ATV
# 2          False         355.0  http://www.nps.gov/badl/           Biking
# 3          False         355.0  http://www.nps.gov/badl/          Camping
# 4          False         355.0  http://www.nps.gov/badl/  Compass and GPS
#
#   Available Amenity  Park Latitude  Park Longitude Entrance Fees
# 0  ATM/Cash Machine      43.685848     -102.482942       $355.00
# 1  ATM/Cash Machine      43.685848     -102.482942       $355.00
# 2  ATM/Cash Machine      43.685848     -102.482942       $355.00
# 3  ATM/Cash Machine      43.685848     -102.482942       $355.00
# 4  ATM/Cash Machine      43.685848     -102.482942       $355.00

# %%
NPS_Cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Park Designation   680 non-null    object
#  1   Park Code          680 non-null    object
#  2   Park Name          680 non-null    object
#  3   Present in States  680 non-null    object
#  4   Free Entrance      680 non-null    bool
#  5   Entrance Fee       680 non-null    float64
#  6   Park Website       680 non-null    object
#  7   Activity Option    680 non-null    object
#  8   Available Amenity  680 non-null    object
#  9   Park Latitude      680 non-null    float64
#  10  Park Longitude     680 non-null    float64
#  11  Entrance Fees      680 non-null    object
# dtypes: bool(1), float64(3), object(8)
# memory usage: 59.2+ KB

# %%
# Drop rows with any empty cells
NPS_Cleaned_df = NPS_Cleaned_df.dropna()

# Display the first few rows of the cleaned DataFrame after dropping empty cells
NPS_Cleaned_df.head()
# Out:
#   Park Designation Park Code               Park Name Present in States  \
# 0    National Park      badl  Badlands National Park                SD
# 1    National Park      badl  Badlands National Park                SD
# 2    National Park      badl  Badlands National Park                SD
# 3    National Park      badl  Badlands National Park                SD
# 4    National Park      badl  Badlands National Park                SD
#
#    Free Entrance  Entrance Fee              Park Website  Activity Option  \
# 0          False         355.0  http://www.nps.gov/badl/        Astronomy
# 1          False         355.0  http://www.nps.gov/badl/     Auto and ATV
# 2          False         355.0  http://www.nps.gov/badl/           Biking
# 3          False         355.0  http://www.nps.gov/badl/          Camping
# 4          False         355.0  http://www.nps.gov/badl/  Compass and GPS
#
#   Available Amenity  Park Latitude  Park Longitude Entrance Fees
# 0  ATM/Cash Machine      43.685848     -102.482942       $355.00
# 1  ATM/Cash Machine      43.685848     -102.482942       $355.00
# 2  ATM/Cash Machine      43.685848     -102.482942       $355.00
# 3  ATM/Cash Machine      43.685848     -102.482942       $355.00
# 4  ATM/Cash Machine      43.685848     -102.482942       $355.00

# %%
NPS_Cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Park Designation   680 non-null    object
#  1   Park Code          680 non-null    object
#  2   Park Name          680 non-null    object
#  3   Present in States  680 non-null    object
#  4   Free Entrance      680 non-null    bool
#  5   Entrance Fee       680 non-null    float64
#  6   Park Website       680 non-null    object
#  7   Activity Option    680 non-null    object
#  8   Available Amenity  680 non-null    object
#  9   Park Latitude      680 non-null    float64
#  10  Park Longitude     680 non-null    float64
#  11  Entrance Fees      680 non-null    object
# dtypes: bool(1), float64(3), object(8)
# memory usage: 59.2+ KB

# %%
# Export DataFrame to a CSV file
NPS_Cleaned_df.to_csv('NPS_Cleaned_Data.csv', index=False)

# Export DataFrame to a JSON file
NPS_Cleaned_df.to_json('NPS_Cleaned_Data.json', orient='records')

print("DataFrame exported to CSV and JSON files successfully.")
# Out:
# DataFrame exported to CSV and JSON files successfully.

# %%
import os
import shutil

# Define the file paths for the original and destination folders
destination_folder = '../Load'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Define the file names and paths
files = {
    'NPS_Cleaned_Data.csv': 'NPS_Cleaned_Data.csv',
    'NPS_Cleaned_Data.json': 'NPS_Cleaned_Data.json'
}

# Copy the file to the destination folder
for target_name, source_path in files.items():
    if os.path.exists(source_path):
        shutil.copy(source_path, os.path.join(destination_folder, target_name))

print(f"Files copied successfully to {destination_folder}: {os.listdir(destination_folder)}")
# Out:
# Files copied successfully to ../Load: ['MongoDB', 'NPS_Cleaned_Data.csv', 'NPS_Cleaned_Data.json', 'SQL']
