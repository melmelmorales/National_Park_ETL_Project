# %% [markdown]
# ### Step 1: Import Dependencies required to perform data transformation steps

# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Step 2: Read in csv files containing data extractions from various API calls to the National Park Service webpage.

# %%
NPS_ThingsToDo_df = pd.read_csv("../Extract/NPS Amenities Info/NPS_Project_Extracted_Data/nps_ttd_data.csv")
NPS_ThingsToDo_df.head(5)
# Out:
#                                                 tags  \
# 0  ['Acadia National Park', 'Echo Lake', 'echo la...
# 1  ['stargazing', 'night skies', 'Acadia National...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                     location  isReservationRequired  \
# 0                            Echo Lake Beach                  False
# 1                          Cadillac Mountain                  False
# 2                       Acadia Mountain Loop                  False
# 3   Sargent and Penobscot Mountains from JPH                  False
# 4                           Jordan Pond Loop                  False
#
#    arePetsPermitted                                         activities  \
# 0              True  [{'id': '587BB2D3-EC35-41B2-B3F7-A39E2B088AEE'...
# 1              True  [{'id': 'D37A0003-8317-4F04-8FB0-4CF0A272E195'...
# 2              True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
# 3              True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
# 4              True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
#
#   amenities  doFeesApply                        season   duration parkCode  \
# 0        []        False                    ['Summer']        NaN     acad
# 1        []        False  ['Spring', 'Summer', 'Fall']        NaN     acad
# 2        []        False  ['Spring', 'Summer', 'Fall']  2-3 Hours     acad
# 3        []        False  ['Spring', 'Summer', 'Fall']        NaN     acad
# 4        []        False  ['Spring', 'Summer', 'Fall']  1-2 Hours     acad
#
#      designation              fullName states
# 0  National Park  Acadia National Park     ME
# 1  National Park  Acadia National Park     ME
# 2  National Park  Acadia National Park     ME
# 3  National Park  Acadia National Park     ME
# 4  National Park  Acadia National Park     ME

# %%
NPS_ThingsToDo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tags                   87 non-null     object
#  1   location               83 non-null     object
#  2   isReservationRequired  87 non-null     bool
#  3   arePetsPermitted       87 non-null     bool
#  4   activities             87 non-null     object
#  5   amenities              87 non-null     object
#  6   doFeesApply            87 non-null     bool
#  7   season                 87 non-null     object
#  8   duration               50 non-null     object
#  9   parkCode               87 non-null     object
#  10  designation            87 non-null     object
#  11  fullName               87 non-null     object
#  12  states                 87 non-null     object
# dtypes: bool(3), object(10)
# memory usage: 7.2+ KB

# %%
# Remove "[" and "]" from the "tags" column
NPS_ThingsToDo_df['tags'] = NPS_ThingsToDo_df['tags'].str.strip('[]').str.replace("'", "")

# Split the "tags" column into multiple columns dynamically
tags_split = NPS_ThingsToDo_df['tags'].str.split(',', expand=True)

# Rename the columns to tag1, tag2, tag3, and so forth
tags_split.columns = [f"tag{i+1}" for i in range(tags_split.shape[1])]

# Concatenate the split columns with the original DataFrame
NPS_ThingsToDo_df = pd.concat([NPS_ThingsToDo_df, tags_split], axis=1)

# Display the updated DataFrame
NPS_ThingsToDo_df
# Out:
#                                                  tags  \
# 0   Acadia National Park, Echo Lake, echo lake bea...
# 1   stargazing, night skies, Acadia National Park,...
# 2
# 3
# 4
# ..                                                ...
# 82  Acadia National Park, lakes, great ponds, swim...
# 83  Acadia National Park, Sand Beach, swimming, At...
# 84  Acadia National Park, birding, ornithology, se...
# 85  Acadia National Park, birding, birdwatching, i...
# 86  Acadia National Park, birding, birdwatching, p...
#
#                                      location  isReservationRequired  \
# 0                             Echo Lake Beach                  False
# 1                           Cadillac Mountain                  False
# 2                        Acadia Mountain Loop                  False
# 3    Sargent and Penobscot Mountains from JPH                  False
# 4                            Jordan Pond Loop                  False
# ..                                        ...                    ...
# 82                    Lake Wood Swimming Area                  False
# 83                                 Sand Beach                  False
# 84                        Seawall Picnic Area                  False
# 85                               Isle au Haut                  False
# 86                                        NaN                  False
#
#     arePetsPermitted                                         activities  \
# 0               True  [{'id': '587BB2D3-EC35-41B2-B3F7-A39E2B088AEE'...
# 1               True  [{'id': 'D37A0003-8317-4F04-8FB0-4CF0A272E195'...
# 2               True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
# 3               True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
# 4               True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
# ..               ...                                                ...
# 82              True  [{'id': '587BB2D3-EC35-41B2-B3F7-A39E2B088AEE'...
# 83              True  [{'id': '587BB2D3-EC35-41B2-B3F7-A39E2B088AEE'...
# 84              True  [{'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF'...
# 85              True  [{'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF'...
# 86              True  [{'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF'...
#
#    amenities  doFeesApply                                  season   duration  \
# 0         []        False                              ['Summer']        NaN
# 1         []        False            ['Spring', 'Summer', 'Fall']        NaN
# 2         []        False            ['Spring', 'Summer', 'Fall']  2-3 Hours
# 3         []        False            ['Spring', 'Summer', 'Fall']        NaN
# 4         []        False            ['Spring', 'Summer', 'Fall']  1-2 Hours
# ..       ...          ...                                     ...        ...
# 82        []        False                              ['Summer']        NaN
# 83        []        False            ['Spring', 'Summer', 'Fall']        NaN
# 84        []        False  ['Winter', 'Spring', 'Summer', 'Fall']        NaN
# 85        []        False            ['Spring', 'Summer', 'Fall']        NaN
# 86        []        False                    ['Spring', 'Summer']        NaN
#
#    parkCode  ...                  tag7  tag8  tag9 tag10 tag11 tag12 tag13  \
# 0      acad  ...           great ponds  None  None  None  None  None  None
# 1      acad  ...   mount desert island  None  None  None  None  None  None
# 2      acad  ...                  None  None  None  None  None  None  None
# 3      acad  ...                  None  None  None  None  None  None  None
# 4      acad  ...                  None  None  None  None  None  None  None
# ..      ...  ...                   ...   ...   ...   ...   ...   ...   ...
# 82     acad  ...                  None  None  None  None  None  None  None
# 83     acad  ...                  None  None  None  None  None  None  None
# 84     acad  ...          birdwatching  None  None  None  None  None  None
# 85     acad  ...                  None  None  None  None  None  None  None
# 86     acad  ...                  None  None  None  None  None  None  None
#
#    tag14 tag15 tag16
# 0   None  None  None
# 1   None  None  None
# 2   None  None  None
# 3   None  None  None
# 4   None  None  None
# ..   ...   ...   ...
# 82  None  None  None
# 83  None  None  None
# 84  None  None  None
# 85  None  None  None
# 86  None  None  None
#
# [87 rows x 29 columns]

# %%
# Remove "[" and "]" from the "seasons" column
NPS_ThingsToDo_df['season'] = NPS_ThingsToDo_df['season'].str.strip('[]').str.replace("'", "")

# Split the "tags" column into multiple columns dynamically
season_split = NPS_ThingsToDo_df['season'].str.split(',', expand=True)

# Rename the columns to season1, season2, season3, and so forth
season_split.columns = [f"season{i+1}" for i in range(season_split.shape[1])]

# Concatenate the split columns with the original DataFrame
NPS_ThingsToDo_df = pd.concat([NPS_ThingsToDo_df, season_split], axis=1)

# Display the updated DataFrame
NPS_ThingsToDo_df
# Out:
#                                                  tags  \
# 0   Acadia National Park, Echo Lake, echo lake bea...
# 1   stargazing, night skies, Acadia National Park,...
# 2
# 3
# 4
# ..                                                ...
# 82  Acadia National Park, lakes, great ponds, swim...
# 83  Acadia National Park, Sand Beach, swimming, At...
# 84  Acadia National Park, birding, ornithology, se...
# 85  Acadia National Park, birding, birdwatching, i...
# 86  Acadia National Park, birding, birdwatching, p...
#
#                                      location  isReservationRequired  \
# 0                             Echo Lake Beach                  False
# 1                           Cadillac Mountain                  False
# 2                        Acadia Mountain Loop                  False
# 3    Sargent and Penobscot Mountains from JPH                  False
# 4                            Jordan Pond Loop                  False
# ..                                        ...                    ...
# 82                    Lake Wood Swimming Area                  False
# 83                                 Sand Beach                  False
# 84                        Seawall Picnic Area                  False
# 85                               Isle au Haut                  False
# 86                                        NaN                  False
#
#     arePetsPermitted                                         activities  \
# 0               True  [{'id': '587BB2D3-EC35-41B2-B3F7-A39E2B088AEE'...
# 1               True  [{'id': 'D37A0003-8317-4F04-8FB0-4CF0A272E195'...
# 2               True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
# 3               True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
# 4               True  [{'id': '45261C0A-00D8-4C27-A1F8-029F933A0D34'...
# ..               ...                                                ...
# 82              True  [{'id': '587BB2D3-EC35-41B2-B3F7-A39E2B088AEE'...
# 83              True  [{'id': '587BB2D3-EC35-41B2-B3F7-A39E2B088AEE'...
# 84              True  [{'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF'...
# 85              True  [{'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF'...
# 86              True  [{'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF'...
#
#    amenities  doFeesApply                        season   duration parkCode  \
# 0         []        False                        Summer        NaN     acad
# 1         []        False          Spring, Summer, Fall        NaN     acad
# 2         []        False          Spring, Summer, Fall  2-3 Hours     acad
# 3         []        False          Spring, Summer, Fall        NaN     acad
# 4         []        False          Spring, Summer, Fall  1-2 Hours     acad
# ..       ...          ...                           ...        ...      ...
# 82        []        False                        Summer        NaN     acad
# 83        []        False          Spring, Summer, Fall        NaN     acad
# 84        []        False  Winter, Spring, Summer, Fall        NaN     acad
# 85        []        False          Spring, Summer, Fall        NaN     acad
# 86        []        False                Spring, Summer        NaN     acad
#
#     ... tag11 tag12 tag13 tag14 tag15 tag16 season1  season2  season3 season4
# 0   ...  None  None  None  None  None  None  Summer     None     None    None
# 1   ...  None  None  None  None  None  None  Spring   Summer     Fall    None
# 2   ...  None  None  None  None  None  None  Spring   Summer     Fall    None
# 3   ...  None  None  None  None  None  None  Spring   Summer     Fall    None
# 4   ...  None  None  None  None  None  None  Spring   Summer     Fall    None
# ..  ...   ...   ...   ...   ...   ...   ...     ...      ...      ...     ...
# 82  ...  None  None  None  None  None  None  Summer     None     None    None
# 83  ...  None  None  None  None  None  None  Spring   Summer     Fall    None
# 84  ...  None  None  None  None  None  None  Winter   Spring   Summer    Fall
# 85  ...  None  None  None  None  None  None  Spring   Summer     Fall    None
# 86  ...  None  None  None  None  None  None  Spring   Summer     None    None
#
# [87 rows x 33 columns]

# %%
# Remove "[" and "]" from the "activities" column
NPS_ThingsToDo_df['activities'] = NPS_ThingsToDo_df['season'].str.strip('[]').str.replace("'", "")

NPS_ThingsToDo_df
# Out:
#                                                  tags  \
# 0   Acadia National Park, Echo Lake, echo lake bea...
# 1   stargazing, night skies, Acadia National Park,...
# 2
# 3
# 4
# ..                                                ...
# 82  Acadia National Park, lakes, great ponds, swim...
# 83  Acadia National Park, Sand Beach, swimming, At...
# 84  Acadia National Park, birding, ornithology, se...
# 85  Acadia National Park, birding, birdwatching, i...
# 86  Acadia National Park, birding, birdwatching, p...
#
#                                      location  isReservationRequired  \
# 0                             Echo Lake Beach                  False
# 1                           Cadillac Mountain                  False
# 2                        Acadia Mountain Loop                  False
# 3    Sargent and Penobscot Mountains from JPH                  False
# 4                            Jordan Pond Loop                  False
# ..                                        ...                    ...
# 82                    Lake Wood Swimming Area                  False
# 83                                 Sand Beach                  False
# 84                        Seawall Picnic Area                  False
# 85                               Isle au Haut                  False
# 86                                        NaN                  False
#
#     arePetsPermitted                    activities amenities  doFeesApply  \
# 0               True                        Summer        []        False
# 1               True          Spring, Summer, Fall        []        False
# 2               True          Spring, Summer, Fall        []        False
# 3               True          Spring, Summer, Fall        []        False
# 4               True          Spring, Summer, Fall        []        False
# ..               ...                           ...       ...          ...
# 82              True                        Summer        []        False
# 83              True          Spring, Summer, Fall        []        False
# 84              True  Winter, Spring, Summer, Fall        []        False
# 85              True          Spring, Summer, Fall        []        False
# 86              True                Spring, Summer        []        False
#
#                           season   duration parkCode  ... tag11 tag12 tag13  \
# 0                         Summer        NaN     acad  ...  None  None  None
# 1           Spring, Summer, Fall        NaN     acad  ...  None  None  None
# 2           Spring, Summer, Fall  2-3 Hours     acad  ...  None  None  None
# 3           Spring, Summer, Fall        NaN     acad  ...  None  None  None
# 4           Spring, Summer, Fall  1-2 Hours     acad  ...  None  None  None
# ..                           ...        ...      ...  ...   ...   ...   ...
# 82                        Summer        NaN     acad  ...  None  None  None
# 83          Spring, Summer, Fall        NaN     acad  ...  None  None  None
# 84  Winter, Spring, Summer, Fall        NaN     acad  ...  None  None  None
# 85          Spring, Summer, Fall        NaN     acad  ...  None  None  None
# 86                Spring, Summer        NaN     acad  ...  None  None  None
#
#    tag14 tag15 tag16 season1  season2  season3 season4
# 0   None  None  None  Summer     None     None    None
# 1   None  None  None  Spring   Summer     Fall    None
# 2   None  None  None  Spring   Summer     Fall    None
# 3   None  None  None  Spring   Summer     Fall    None
# 4   None  None  None  Spring   Summer     Fall    None
# ..   ...   ...   ...     ...      ...      ...     ...
# 82  None  None  None  Summer     None     None    None
# 83  None  None  None  Spring   Summer     Fall    None
# 84  None  None  None  Winter   Spring   Summer    Fall
# 85  None  None  None  Spring   Summer     Fall    None
# 86  None  None  None  Spring   Summer     None    None
#
# [87 rows x 33 columns]

# %%
# Drop the original "tags" and "seasons" columns
NPS_ThingsToDo_df = NPS_ThingsToDo_df.drop(columns=['tags', 'season'])

NPS_ThingsToDo_df.head(10)
# Out:
#                                             location  isReservationRequired  \
# 0                                    Echo Lake Beach                  False
# 1                                  Cadillac Mountain                  False
# 2                               Acadia Mountain Loop                  False
# 3           Sargent and Penobscot Mountains from JPH                  False
# 4                                   Jordan Pond Loop                  False
# 5  Sieur de Monts to Jesup Path and Hemlock Road ...                  False
# 6                       Sieur de Monts to Sand Beach                  False
# 7  Beech Cliff Trail, Beech Cliff Loop, and Canad...                  False
# 8                                   Great Head Trail                  False
# 9                               The Ocean Path Trail                  False
#
#    arePetsPermitted            activities amenities  doFeesApply   duration  \
# 0              True                Summer        []        False        NaN
# 1              True  Spring, Summer, Fall        []        False        NaN
# 2              True  Spring, Summer, Fall        []        False  2-3 Hours
# 3              True  Spring, Summer, Fall        []        False        NaN
# 4              True  Spring, Summer, Fall        []        False  1-2 Hours
# 5              True  Spring, Summer, Fall        []        False  1-2 Hours
# 6              True  Spring, Summer, Fall        []        False  2-4 Hours
# 7             False  Spring, Summer, Fall        []        False  2-4 Hours
# 8              True  Spring, Summer, Fall        []        False  1-2 Hours
# 9              True  Spring, Summer, Fall        []        False  1-2 Hours
#
#   parkCode    designation              fullName  ... tag11 tag12 tag13 tag14  \
# 0     acad  National Park  Acadia National Park  ...  None  None  None  None
# 1     acad  National Park  Acadia National Park  ...  None  None  None  None
# 2     acad  National Park  Acadia National Park  ...  None  None  None  None
# 3     acad  National Park  Acadia National Park  ...  None  None  None  None
# 4     acad  National Park  Acadia National Park  ...  None  None  None  None
# 5     acad  National Park  Acadia National Park  ...  None  None  None  None
# 6     acad  National Park  Acadia National Park  ...  None  None  None  None
# 7     acad  National Park  Acadia National Park  ...  None  None  None  None
# 8     acad  National Park  Acadia National Park  ...  None  None  None  None
# 9     acad  National Park  Acadia National Park  ...  None  None  None  None
#
#   tag15 tag16 season1  season2 season3 season4
# 0  None  None  Summer     None    None    None
# 1  None  None  Spring   Summer    Fall    None
# 2  None  None  Spring   Summer    Fall    None
# 3  None  None  Spring   Summer    Fall    None
# 4  None  None  Spring   Summer    Fall    None
# 5  None  None  Spring   Summer    Fall    None
# 6  None  None  Spring   Summer    Fall    None
# 7  None  None  Spring   Summer    Fall    None
# 8  None  None  Spring   Summer    Fall    None
# 9  None  None  Spring   Summer    Fall    None
#
# [10 rows x 31 columns]

# %%
# Rename column to prepare for merge
NPS_ThingsToDo_df.rename(columns={"parkCode": "park_code", "fullName": "park_name", "designation": "park_designation"}, inplace=True)
NPS_ThingsToDo_df.head(5)
# Out:
#                                     location  isReservationRequired  \
# 0                            Echo Lake Beach                  False
# 1                          Cadillac Mountain                  False
# 2                       Acadia Mountain Loop                  False
# 3   Sargent and Penobscot Mountains from JPH                  False
# 4                           Jordan Pond Loop                  False
#
#    arePetsPermitted            activities amenities  doFeesApply   duration  \
# 0              True                Summer        []        False        NaN
# 1              True  Spring, Summer, Fall        []        False        NaN
# 2              True  Spring, Summer, Fall        []        False  2-3 Hours
# 3              True  Spring, Summer, Fall        []        False        NaN
# 4              True  Spring, Summer, Fall        []        False  1-2 Hours
#
#   park_code park_designation             park_name  ... tag11 tag12 tag13  \
# 0      acad    National Park  Acadia National Park  ...  None  None  None
# 1      acad    National Park  Acadia National Park  ...  None  None  None
# 2      acad    National Park  Acadia National Park  ...  None  None  None
# 3      acad    National Park  Acadia National Park  ...  None  None  None
# 4      acad    National Park  Acadia National Park  ...  None  None  None
#
#   tag14 tag15 tag16 season1  season2 season3 season4
# 0  None  None  None  Summer     None    None    None
# 1  None  None  None  Spring   Summer    Fall    None
# 2  None  None  None  Spring   Summer    Fall    None
# 3  None  None  None  Spring   Summer    Fall    None
# 4  None  None  None  Spring   Summer    Fall    None
#
# [5 rows x 31 columns]

# %%
NPS_ThingsToDo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   location               83 non-null     object
#  1   isReservationRequired  87 non-null     bool
#  2   arePetsPermitted       87 non-null     bool
#  3   activities             87 non-null     object
#  4   amenities              87 non-null     object
#  5   doFeesApply            87 non-null     bool
#  6   duration               50 non-null     object
#  7   park_code              87 non-null     object
#  8   park_designation       87 non-null     object
#  9   park_name              87 non-null     object
#  10  states                 87 non-null     object
#  11  tag1                   87 non-null     object
#  12  tag2                   75 non-null     object
#  13  tag3                   75 non-null     object
#  14  tag4                   74 non-null     object
#  15  tag5                   73 non-null     object
#  16  tag6                   70 non-null     object
#  17  tag7                   62 non-null     object
#  18  tag8                   51 non-null     object
#  19  tag9                   39 non-null     object
#  20  tag10                  26 non-null     object
#  21  tag11                  12 non-null     object
#  22  tag12                  7 non-null      object
#  23  tag13                  3 non-null      object
#  24  tag14                  1 non-null      object
#  25  tag15                  1 non-null      object
#  26  tag16                  1 non-null      object
#  27  season1                87 non-null     object
#  28  season2                81 non-null     object
#  29  season3                78 non-null     object
#  30  season4                31 non-null     object
# dtypes: bool(3), object(28)
# memory usage: 19.4+ KB

# %%
NPS_AmenitiesByPlace_df = pd.read_csv("../Extract/NPS Amenities Info/NPS_Project_Extracted_Data/nps_amen_place_data.csv")
NPS_AmenitiesByPlace_df.head(5)
# Out:
#                              amenity_id      amenity_name park_code  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      badl
# 1  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      bibe
# 2  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      brca
# 3  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      cabr
# 4  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      deva
#
#                     park_name park_states   park_designation  \
# 0      Badlands National Park          SD      National Park
# 1      Big Bend National Park          TX      National Park
# 2  Bryce Canyon National Park          UT      National Park
# 3  Cabrillo National Monument          CA  National Monument
# 4  Death Valley National Park       CA,NV      National Park
#
#                    park_url
# 0  http://www.nps.gov/badl/
# 1  http://www.nps.gov/bibe/
# 2  http://www.nps.gov/brca/
# 3  http://www.nps.gov/cabr/
# 4  http://www.nps.gov/deva/

# %%
NPS_AmenitiesByPlace_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8652 entries, 0 to 8651
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   amenity_id        8652 non-null   object
#  1   amenity_name      8652 non-null   object
#  2   park_code         8652 non-null   object
#  3   park_name         8652 non-null   object
#  4   park_states       8652 non-null   object
#  5   park_designation  8216 non-null   object
#  6   park_url          8640 non-null   object
# dtypes: object(7)
# memory usage: 473.3+ KB

# %%
NPS_Parks_df = pd.read_csv("../Extract/NPS Amenities Info/NPS_Project_Extracted_Data/nps_parks_data.csv")
NPS_Parks_df.head(5)
# Out:
#                                 park_id                            park_url  \
# 0  77E0D7F0-1942-494A-ACE2-9004D2BDC59E  https://www.nps.gov/abli/index.htm
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 2  E4C7784E-66A0-4D44-87D0-3E072F5FEF43  https://www.nps.gov/adam/index.htm
# 3  1A47416F-DAA3-4137-9F30-14AF86B4E547  https://www.nps.gov/afam/index.htm
# 4  E6E1D22A-7A89-47F8-813C-B611059A8CF9  https://www.nps.gov/afbg/index.htm
#
#                                            park_name park_code  park_latitude  \
# 0  Abraham Lincoln Birthplace National Historical...      abli      37.585866
# 1                               Acadia National Park      acad      44.409286
# 2                     Adams National Historical Park      adam      42.255396
# 3                African American Civil War Memorial      afam      38.916600
# 4            African Burial Ground National Monument      afbg      40.714527
#
#    park_longitude          park_designation
# 0      -85.673305  National Historical Park
# 1      -68.247501             National Park
# 2      -71.011604  National Historical Park
# 3      -77.026000                       NaN
# 4      -74.004474         National Monument

# %%
NPS_Parks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   park_id           471 non-null    object
#  1   park_url          471 non-null    object
#  2   park_name         471 non-null    object
#  3   park_code         471 non-null    object
#  4   park_latitude     470 non-null    float64
#  5   park_longitude    470 non-null    float64
#  6   park_designation  435 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 25.9+ KB

# %%
NPS_ActivitiesByPark_df = pd.read_csv("../Extract/NPS_Activities_Fees/NPS_Project_Extracted_Data/activities_parks.csv")
NPS_ActivitiesByPark_df.head(5)
# Out:
#                             activity_id     activity_name  \
# 0  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 1  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 2  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 3  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 4  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
#
#                designation                                   fullName  \
# 0            National Park                       Acadia National Park
# 1        National Monument    African Burial Ground National Monument
# 2        National Monument        Agate Fossil Beds National Monument
# 3        National Monument  Alibates Flint Quarries National Monument
# 4  National Historic Trail        Ala Kahakai National Historic Trail
#
#                       name parkCode states                                 url
# 0                   Acadia     acad     ME  https://www.nps.gov/acad/index.htm
# 1    African Burial Ground     afbg     NY  https://www.nps.gov/afbg/index.htm
# 2        Agate Fossil Beds     agfo     NE  https://www.nps.gov/agfo/index.htm
# 3  Alibates Flint Quarries     alfl     TX  https://www.nps.gov/alfl/index.htm
# 4              Ala Kahakai     alka     HI  https://www.nps.gov/alka/index.htm

# %%
# Rename column to prepare for merge
NPS_ActivitiesByPark_df.rename(columns={"parkCode": "park_code", "fullName": "park_name", "designation": "park_designation", "states": "park_states", "url": "park_url"}, inplace=True)
NPS_ActivitiesByPark_df.head(5)
# Out:
#                             activity_id     activity_name  \
# 0  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 1  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 2  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 3  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 4  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
#
#           park_designation                                  park_name  \
# 0            National Park                       Acadia National Park
# 1        National Monument    African Burial Ground National Monument
# 2        National Monument        Agate Fossil Beds National Monument
# 3        National Monument  Alibates Flint Quarries National Monument
# 4  National Historic Trail        Ala Kahakai National Historic Trail
#
#                       name park_code park_states  \
# 0                   Acadia      acad          ME
# 1    African Burial Ground      afbg          NY
# 2        Agate Fossil Beds      agfo          NE
# 3  Alibates Flint Quarries      alfl          TX
# 4              Ala Kahakai      alka          HI
#
#                              park_url
# 0  https://www.nps.gov/acad/index.htm
# 1  https://www.nps.gov/afbg/index.htm
# 2  https://www.nps.gov/agfo/index.htm
# 3  https://www.nps.gov/alfl/index.htm
# 4  https://www.nps.gov/alka/index.htm

# %%
NPS_ActivitiesByPark_df.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4013 entries, 0 to 4012
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   activity_id       4013 non-null   object
#  1   activity_name     4013 non-null   object
#  2   park_designation  3843 non-null   object
#  3   park_name         4013 non-null   object
#  4   name              4013 non-null   object
#  5   park_code         4013 non-null   object
#  6   park_states       4006 non-null   object
#  7   park_url          4013 non-null   object
# dtypes: object(8)
# memory usage: 250.9+ KB

# %%
NPS_EntranceFees_df = pd.read_csv("../Extract/NPS_Activities_Fees/NPS_Project_Extracted_Data/feespasses.csv")
NPS_EntranceFees_df.head(5)
# Out:
#   parkCode  totalFees  averageFees  totalPasses  averagePasses  isFeeFreePark  \
# 0     acad       91.0    13.000000         70.0           70.0          False
# 1     arch       72.0    18.000000         55.0           55.0          False
# 2     badl      355.0    50.714286         55.0           55.0          False
# 3     bibe      425.0    60.714286         55.0           55.0          False
# 4     bisc        0.0     0.000000          0.0            0.0           True
#
#                              entrancePassDescription  \
# 0  A park entrance pass is required year-round. A...
# 1                                                NaN
# 2                                                NaN
# 3  Big Bend National Park Annual Pass: $55 Covers...
# 4                                                NaN
#
#                               entranceFeeDescription  \
# 0  A park entrance pass is required year-round at...
# 1                                                NaN
# 2  Badlands National Park charges an entrance fee...
# 3  All vehicles entering Big Bend National Park a...
# 4                                                NaN
#
#                                        feesAtWorkUrl
# 0    https://www.nps.gov/acad/planyourvisit/fees.htm
# 1  https://www.nps.gov/arch/learn/management/your...
# 2                                                NaN
# 3  https://www.nps.gov/bibe/learn/management/your...
# 4                                                NaN

# %%
# Rename column to prepare for merge
NPS_EntranceFees_df.rename(columns={"parkCode": "park_code"}, inplace=True)
NPS_EntranceFees_df.head(5)
# Out:
#   park_code  totalFees  averageFees  totalPasses  averagePasses  \
# 0      acad       91.0    13.000000         70.0           70.0
# 1      arch       72.0    18.000000         55.0           55.0
# 2      badl      355.0    50.714286         55.0           55.0
# 3      bibe      425.0    60.714286         55.0           55.0
# 4      bisc        0.0     0.000000          0.0            0.0
#
#    isFeeFreePark                            entrancePassDescription  \
# 0          False  A park entrance pass is required year-round. A...
# 1          False                                                NaN
# 2          False                                                NaN
# 3          False  Big Bend National Park Annual Pass: $55 Covers...
# 4           True                                                NaN
#
#                               entranceFeeDescription  \
# 0  A park entrance pass is required year-round at...
# 1                                                NaN
# 2  Badlands National Park charges an entrance fee...
# 3  All vehicles entering Big Bend National Park a...
# 4                                                NaN
#
#                                        feesAtWorkUrl
# 0    https://www.nps.gov/acad/planyourvisit/fees.htm
# 1  https://www.nps.gov/arch/learn/management/your...
# 2                                                NaN
# 3  https://www.nps.gov/bibe/learn/management/your...
# 4                                                NaN

# %%
NPS_EntranceFees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   park_code                6 non-null      object
#  1   totalFees                6 non-null      float64
#  2   averageFees              6 non-null      float64
#  3   totalPasses              6 non-null      float64
#  4   averagePasses            6 non-null      float64
#  5   isFeeFreePark            6 non-null      bool
#  6   entrancePassDescription  2 non-null      object
#  7   entranceFeeDescription   3 non-null      object
#  8   feesAtWorkUrl            3 non-null      object
# dtypes: bool(1), float64(4), object(4)
# memory usage: 518.0+ bytes

# %%
# Additional line to add Melissa's output file(s) once available
# NPS_GeoLocation_df = pd.read_csv("Extract/NPS_Park_Boundaries/NPS_Project_Extracted_Data/filename.csv")

# %% [markdown]
# ### Step 3: Edit data to create a single, comprehensive, cleaned dataset for use in analysis

# %%
# Combine Things To Do and Parks dataframes
ThingsToDoByPark_df = pd.merge(NPS_ThingsToDo_df, NPS_Parks_df, on=["park_code", "park_name"])
ThingsToDoByPark_df.head(5)
# Out:
#                                     location  isReservationRequired  \
# 0                            Echo Lake Beach                  False
# 1                          Cadillac Mountain                  False
# 2                       Acadia Mountain Loop                  False
# 3   Sargent and Penobscot Mountains from JPH                  False
# 4                           Jordan Pond Loop                  False
#
#    arePetsPermitted            activities amenities  doFeesApply   duration  \
# 0              True                Summer        []        False        NaN
# 1              True  Spring, Summer, Fall        []        False        NaN
# 2              True  Spring, Summer, Fall        []        False  2-3 Hours
# 3              True  Spring, Summer, Fall        []        False        NaN
# 4              True  Spring, Summer, Fall        []        False  1-2 Hours
#
#   park_code park_designation_x             park_name  ... tag16 season1  \
# 0      acad      National Park  Acadia National Park  ...  None  Summer
# 1      acad      National Park  Acadia National Park  ...  None  Spring
# 2      acad      National Park  Acadia National Park  ...  None  Spring
# 3      acad      National Park  Acadia National Park  ...  None  Spring
# 4      acad      National Park  Acadia National Park  ...  None  Spring
#
#    season2 season3 season4                               park_id  \
# 0     None    None    None  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 1   Summer    Fall    None  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 2   Summer    Fall    None  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 3   Summer    Fall    None  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 4   Summer    Fall    None  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
#
#                              park_url park_latitude park_longitude  \
# 0  https://www.nps.gov/acad/index.htm     44.409286     -68.247501
# 1  https://www.nps.gov/acad/index.htm     44.409286     -68.247501
# 2  https://www.nps.gov/acad/index.htm     44.409286     -68.247501
# 3  https://www.nps.gov/acad/index.htm     44.409286     -68.247501
# 4  https://www.nps.gov/acad/index.htm     44.409286     -68.247501
#
#   park_designation_y
# 0      National Park
# 1      National Park
# 2      National Park
# 3      National Park
# 4      National Park
#
# [5 rows x 36 columns]

# %%
# Combine Activity and Amenity dataframes
Amen_Act_Loc_df = pd.merge(NPS_AmenitiesByPlace_df, NPS_ActivitiesByPark_df, on=["park_code", "park_name"])
Amen_Act_Loc_df.head(5)
# Out:
#                              amenity_id      amenity_name park_code  \
# 0  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      badl
# 1  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      badl
# 2  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      badl
# 3  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      badl
# 4  A1B0AD01-740C-41E7-8412-FBBEDD5F1443  ATM/Cash Machine      badl
#
#                 park_name park_states_x park_designation_x  \
# 0  Badlands National Park            SD      National Park
# 1  Badlands National Park            SD      National Park
# 2  Badlands National Park            SD      National Park
# 3  Badlands National Park            SD      National Park
# 4  Badlands National Park            SD      National Park
#
#                  park_url_x                           activity_id  \
# 0  http://www.nps.gov/badl/  13A57703-BB1A-41A2-94B8-53B692EB7238
# 1  http://www.nps.gov/badl/  5F723BAD-7359-48FC-98FA-631592256E35
# 2  http://www.nps.gov/badl/  7CE6E935-F839-4FEC-A63E-052B1DEF39D2
# 3  http://www.nps.gov/badl/  A59947B7-3376-49B4-AD02-C0423E08C5F7
# 4  http://www.nps.gov/badl/  C11D3746-5063-4BD0-B245-7178D1AD866C
#
#      activity_name park_designation_y      name park_states_y  \
# 0        Astronomy      National Park  Badlands            SD
# 1     Auto and ATV      National Park  Badlands            SD
# 2           Biking      National Park  Badlands            SD
# 3          Camping      National Park  Badlands            SD
# 4  Compass and GPS      National Park  Badlands            SD
#
#                            park_url_y
# 0  https://www.nps.gov/badl/index.htm
# 1  https://www.nps.gov/badl/index.htm
# 2  https://www.nps.gov/badl/index.htm
# 3  https://www.nps.gov/badl/index.htm
# 4  https://www.nps.gov/badl/index.htm

# %%
# Combine Activity/Amenity By Park dataframe with Things To By Park dataframe 
Act_Amen_TTD_Park_df = pd.merge(ThingsToDoByPark_df, Amen_Act_Loc_df, on=["park_code", "park_name"])
Act_Amen_TTD_Park_df.head(5)
# Out:
#           location  isReservationRequired  arePetsPermitted activities  \
# 0  Echo Lake Beach                  False              True     Summer
# 1  Echo Lake Beach                  False              True     Summer
# 2  Echo Lake Beach                  False              True     Summer
# 3  Echo Lake Beach                  False              True     Summer
# 4  Echo Lake Beach                  False              True     Summer
#
#   amenities  doFeesApply duration park_code park_designation_x_x  \
# 0        []        False      NaN      acad        National Park
# 1        []        False      NaN      acad        National Park
# 2        []        False      NaN      acad        National Park
# 3        []        False      NaN      acad        National Park
# 4        []        False      NaN      acad        National Park
#
#               park_name  ...      amenity_name park_states_x  \
# 0  Acadia National Park  ...  Accessible Rooms            ME
# 1  Acadia National Park  ...  Accessible Rooms            ME
# 2  Acadia National Park  ...  Accessible Rooms            ME
# 3  Acadia National Park  ...  Accessible Rooms            ME
# 4  Acadia National Park  ...  Accessible Rooms            ME
#
#   park_designation_x_y                park_url_x  \
# 0        National Park  http://www.nps.gov/acad/
# 1        National Park  http://www.nps.gov/acad/
# 2        National Park  http://www.nps.gov/acad/
# 3        National Park  http://www.nps.gov/acad/
# 4        National Park  http://www.nps.gov/acad/
#
#                             activity_id     activity_name  \
# 0  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 1  13A57703-BB1A-41A2-94B8-53B692EB7238         Astronomy
# 2  7CE6E935-F839-4FEC-A63E-052B1DEF39D2            Biking
# 3  071BA73C-1D3C-46D4-A53C-00D5602F7F0E           Boating
# 4  A59947B7-3376-49B4-AD02-C0423E08C5F7           Camping
#
#   park_designation_y_y    name park_states_y  \
# 0        National Park  Acadia            ME
# 1        National Park  Acadia            ME
# 2        National Park  Acadia            ME
# 3        National Park  Acadia            ME
# 4        National Park  Acadia            ME
#
#                            park_url_y
# 0  https://www.nps.gov/acad/index.htm
# 1  https://www.nps.gov/acad/index.htm
# 2  https://www.nps.gov/acad/index.htm
# 3  https://www.nps.gov/acad/index.htm
# 4  https://www.nps.gov/acad/index.htm
#
# [5 rows x 47 columns]

# %%
## This reduces the dataset by to much. Need to approach differently

# Fee_Amen_Act_Loc_df = pd.merge(NPS_EntranceFees_df, NPS_EntranceFees_df, on=["park_code"])
# Fee_Amen_Act_Loc_df.head(5)
# Out:
#   park_code  totalFees_x  averageFees_x  totalPasses_x  averagePasses_x  \
# 0      acad         91.0      13.000000           70.0             70.0
# 1      arch         72.0      18.000000           55.0             55.0
# 2      badl        355.0      50.714286           55.0             55.0
# 3      bibe        425.0      60.714286           55.0             55.0
# 4      bisc          0.0       0.000000            0.0              0.0
#
#    isFeeFreePark_x                          entrancePassDescription_x  \
# 0            False  A park entrance pass is required year-round. A...
# 1            False                                                NaN
# 2            False                                                NaN
# 3            False  Big Bend National Park Annual Pass: $55 Covers...
# 4             True                                                NaN
#
#                             entranceFeeDescription_x  \
# 0  A park entrance pass is required year-round at...
# 1                                                NaN
# 2  Badlands National Park charges an entrance fee...
# 3  All vehicles entering Big Bend National Park a...
# 4                                                NaN
#
#                                      feesAtWorkUrl_x  totalFees_y  \
# 0    https://www.nps.gov/acad/planyourvisit/fees.htm         91.0
# 1  https://www.nps.gov/arch/learn/management/your...         72.0
# 2                                                NaN        355.0
# 3  https://www.nps.gov/bibe/learn/management/your...        425.0
# 4                                                NaN          0.0
#
#    averageFees_y  totalPasses_y  averagePasses_y  isFeeFreePark_y  \
# 0      13.000000           70.0             70.0            False
# 1      18.000000           55.0             55.0            False
# 2      50.714286           55.0             55.0            False
# 3      60.714286           55.0             55.0            False
# 4       0.000000            0.0              0.0             True
#
#                            entrancePassDescription_y  \
# 0  A park entrance pass is required year-round. A...
# 1                                                NaN
# 2                                                NaN
# 3  Big Bend National Park Annual Pass: $55 Covers...
# 4                                                NaN
#
#                             entranceFeeDescription_y  \
# 0  A park entrance pass is required year-round at...
# 1                                                NaN
# 2  Badlands National Park charges an entrance fee...
# 3  All vehicles entering Big Bend National Park a...
# 4                                                NaN
#
#                                      feesAtWorkUrl_y
# 0    https://www.nps.gov/acad/planyourvisit/fees.htm
# 1  https://www.nps.gov/arch/learn/management/your...
# 2                                                NaN
# 3  https://www.nps.gov/bibe/learn/management/your...
# 4                                                NaN

# %%
#Fee_Amen_Act_Loc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   park_code                  6 non-null      object
#  1   totalFees_x                6 non-null      float64
#  2   averageFees_x              6 non-null      float64
#  3   totalPasses_x              6 non-null      float64
#  4   averagePasses_x            6 non-null      float64
#  5   isFeeFreePark_x            6 non-null      bool
#  6   entrancePassDescription_x  2 non-null      object
#  7   entranceFeeDescription_x   3 non-null      object
#  8   feesAtWorkUrl_x            3 non-null      object
#  9   totalFees_y                6 non-null      float64
#  10  averageFees_y              6 non-null      float64
#  11  totalPasses_y              6 non-null      float64
#  12  averagePasses_y            6 non-null      float64
#  13  isFeeFreePark_y            6 non-null      bool
#  14  entrancePassDescription_y  2 non-null      object
#  15  entranceFeeDescription_y   3 non-null      object
#  16  feesAtWorkUrl_y            3 non-null      object
# dtypes: bool(2), float64(8), object(7)
# memory usage: 860.0+ bytes

# %%
# Only keep rows that correspond to a National Park
NPS_dataset_df = Act_Amen_TTD_Park_df[(Act_Amen_TTD_Park_df["park_designation_x_x"] == "National Park")]
NPS_dataset_df.head(5)
# Out:
#           location  isReservationRequired  arePetsPermitted activities  \
# 0  Echo Lake Beach                  False              True     Summer
# 1  Echo Lake Beach                  False              True     Summer
# 2  Echo Lake Beach                  False              True     Summer
# 3  Echo Lake Beach                  False              True     Summer
# 4  Echo Lake Beach                  False              True     Summer
#
#   amenities  doFeesApply duration park_code park_designation_x_x  \
# 0        []        False      NaN      acad        National Park
# 1        []        False      NaN      acad        National Park
# 2        []        False      NaN      acad        National Park
# 3        []        False      NaN      acad        National Park
# 4        []        False      NaN      acad        National Park
#
#               park_name  ...      amenity_name park_states_x  \
# 0  Acadia National Park  ...  Accessible Rooms            ME
# 1  Acadia National Park  ...  Accessible Rooms            ME
# 2  Acadia National Park  ...  Accessible Rooms            ME
# 3  Acadia National Park  ...  Accessible Rooms            ME
# 4  Acadia National Park  ...  Accessible Rooms            ME
#
#   park_designation_x_y                park_url_x  \
# 0        National Park  http://www.nps.gov/acad/
# 1        National Park  http://www.nps.gov/acad/
# 2        National Park  http://www.nps.gov/acad/
# 3        National Park  http://www.nps.gov/acad/
# 4        National Park  http://www.nps.gov/acad/
#
#                             activity_id     activity_name  \
# 0  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture
# 1  13A57703-BB1A-41A2-94B8-53B692EB7238         Astronomy
# 2  7CE6E935-F839-4FEC-A63E-052B1DEF39D2            Biking
# 3  071BA73C-1D3C-46D4-A53C-00D5602F7F0E           Boating
# 4  A59947B7-3376-49B4-AD02-C0423E08C5F7           Camping
#
#   park_designation_y_y    name park_states_y  \
# 0        National Park  Acadia            ME
# 1        National Park  Acadia            ME
# 2        National Park  Acadia            ME
# 3        National Park  Acadia            ME
# 4        National Park  Acadia            ME
#
#                            park_url_y
# 0  https://www.nps.gov/acad/index.htm
# 1  https://www.nps.gov/acad/index.htm
# 2  https://www.nps.gov/acad/index.htm
# 3  https://www.nps.gov/acad/index.htm
# 4  https://www.nps.gov/acad/index.htm
#
# [5 rows x 47 columns]

# %%
NPS_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89784 entries, 0 to 89783
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   location               85656 non-null  object
#  1   isReservationRequired  89784 non-null  bool
#  2   arePetsPermitted       89784 non-null  bool
#  3   activities             89784 non-null  object
#  4   amenities              89784 non-null  object
#  5   doFeesApply            89784 non-null  bool
#  6   duration               51600 non-null  object
#  7   park_code              89784 non-null  object
#  8   park_designation_x_x   89784 non-null  object
#  9   park_name              89784 non-null  object
#  10  states                 89784 non-null  object
#  11  tag1                   89784 non-null  object
#  12  tag2                   77400 non-null  object
#  13  tag3                   77400 non-null  object
#  14  tag4                   76368 non-null  object
#  15  tag5                   75336 non-null  object
#  16  tag6                   72240 non-null  object
#  17  tag7                   63984 non-null  object
#  18  tag8                   52632 non-null  object
#  19  tag9                   40248 non-null  object
#  20  tag10                  26832 non-null  object
#  21  tag11                  12384 non-null  object
#  22  tag12                  7224 non-null   object
#  23  tag13                  3096 non-null   object
#  24  tag14                  1032 non-null   object
#  25  tag15                  1032 non-null   object
#  26  tag16                  1032 non-null   object
#  27  season1                89784 non-null  object
#  28  season2                83592 non-null  object
#  29  season3                80496 non-null  object
#  30  season4                31992 non-null  object
#  31  park_id                89784 non-null  object
#  32  park_url               89784 non-null  object
#  33  park_latitude          89784 non-null  float64
#  34  park_longitude         89784 non-null  float64
#  35  park_designation_y_x   89784 non-null  object
#  36  amenity_id             89784 non-null  object
#  37  amenity_name           89784 non-null  object
#  38  park_states_x          89784 non-null  object
#  39  park_designation_x_y   89784 non-null  object
#  40  park_url_x             89784 non-null  object
#  41  activity_id            89784 non-null  object
#  42  activity_name          89784 non-null  object
#  43  park_designation_y_y   89784 non-null  object
#  44  name                   89784 non-null  object
#  45  park_states_y          89784 non-null  object
#  46  park_url_y             89784 non-null  object
# dtypes: bool(3), float64(2), object(42)
# memory usage: 30.4+ MB

# %%
# View all available columns
print(NPS_dataset_df.columns)
# Out:
# Index(['location', 'isReservationRequired', 'arePetsPermitted', 'activities',
#        'amenities', 'doFeesApply', 'duration', 'park_code',
#        'park_designation_x_x', 'park_name', 'states', 'tag1', 'tag2', 'tag3',
#        'tag4', 'tag5', 'tag6', 'tag7', 'tag8', 'tag9', 'tag10', 'tag11',
#        'tag12', 'tag13', 'tag14', 'tag15', 'tag16', 'season1', 'season2',
#        'season3', 'season4', 'park_id', 'park_url', 'park_latitude',
#        'park_longitude', 'park_designation_y_x', 'amenity_id', 'amenity_name',
#        'park_states_x', 'park_designation_x_y', 'park_url_x', 'activity_id',
#        'activity_name', 'park_designation_y_y', 'name', 'park_states_y',
#        'park_url_y'],
#       dtype='object')

# %%
# Create a DataFrame called NPS_Cleaned_df with only columns useful for downstream data analysis

# Remove fields not useful to data analysis from the dataset
NPS_Cleaned_df = NPS_dataset_df[['amenity_name', 'park_code', 'park_name', 'park_states', 'park_designation_x', 
    'park_url_x', 'activity_name', 'park_latitude', 'park_longitude', 'totalFees', "location", "isReservationRequired",
    'arePetsPermitted','isFeeFreePark']]
    
# Rename the columns 
NPS_Cleaned_df = NPS_Cleaned_df.rename(columns={
    'park_designation_x_x': 'Park Designation',
    'park_code': 'Park Code',
    'park_name': 'Park Name',
    'park_states_x': 'Present in States',
    'isFeeFreePark': 'Free Entrance',
    'totalFees': 'Entrance Fee',
    'park_url_x': 'Park Website',
    'park_latitude': 'Park Latitude',
    'park_longitude': 'Park Longitude',
    'amenity_name': 'Available Amenity',
    'activity_name': 'Activity Option',
    'location': 'Activity Location',
    'isReservationRequired': 'Activity Requires Reservation',
    'arePetsPermitted': 'Pets Allowed',
    'doFeesApply': 'Activity Fee Required',
    'tag1': 'Activity Tag 1',
    'tag2': 'Activity Tag 2',
    'tag3': 'Activity Tag 3',
    'tag4': 'Activity Tag 4',
    'tag5': 'Activity Tag 5',
    'season1': 'Activity Season 1',
    'season2': 'Activity Season 2',
    'season3': 'Activity Season 3',
    'season4': 'Activity Season 4',
})

# Reorder the columns
NPS_Cleaned_df = NPS_Cleaned_df[['Park Designation', 'Park Code', 'Park Name', 'Present in States', 'Free Entrance',
                                'Entrance Fee', 'Park Website', 'Park Latitude', 'Park Longitude', 'Available Amenity', 'Activity Option',
                                'Activity Location', 'Activity Requires Reservation', 'Pets Allowed', 'Activity Fee Required',
                                'Activity Tag 1', 'Activity Tag 2', 'Activity Tag 3', 'Activity Tag 4', 'Activity Tag 5',
                                'Activity Season 1', 'Activity Season 2', 'Activity Season 3', 'Activity Season 4']]

# Format the Entrance Fee column
NPS_Cleaned_df["Entrance Fees"] = NPS_Cleaned_df["Entrance Fee"].map("${:,.2f}".format)

# Display the DataFrame
NPS_Cleaned_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 4
#       1 # Create a DataFrame called NPS_Cleaned_df with only columns useful for downstream data analysis
#       2
#       3 # Remove fields not useful to data analysis from the dataset
# ----> 4 NPS_Cleaned_df = NPS_dataset_df[['amenity_name', 'park_code', 'park_name', 'park_states', 'park_designation_x',
#       5     'park_url_x', 'activity_name', 'park_latitude', 'park_longitude', 'totalFees', "location", "isReservationRequired",
#       6     'arePetsPermitted','isFeeFreePark']]
#       8 # Rename the columns
#       9 NPS_Cleaned_df = NPS_Cleaned_df.rename(columns={
#      10     'park_designation_x_x': 'Park Designation',
#      11     'park_code': 'Park Code',
#    (...)
#      33     'season4': 'Activity Season 4',
#      34 })
#
# File c:\Users\STEFF\anaconda3\envs\dev_2\lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\STEFF\anaconda3\envs\dev_2\lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File c:\Users\STEFF\anaconda3\envs\dev_2\lib\site-packages\pandas\core\indexes\base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['park_states', 'park_designation_x', 'totalFees', 'isFeeFreePark'] not in index"

# %%
NPS_Cleaned_df.info()

# %%
# Drop rows with any empty cells
NPS_Cleaned_df = NPS_Cleaned_df.dropna()

# Display the first few rows of the cleaned DataFrame after dropping empty cells
NPS_Cleaned_df.head()

# %%
NPS_Cleaned_df.info()

# %%
NPS_Cleaned_df.nunique()

# %%
# Export DataFrame to a CSV file
NPS_Cleaned_df.to_csv('NPS_Cleaned_Data.csv', index=False)

# Export DataFrame to a JSON file
NPS_Cleaned_df.to_json('NPS_Cleaned_Data.json', orient='records')

print("DataFrame exported to CSV and JSON files successfully.")

# %%
import os
import shutil

# Define the file paths for the original and destination folders
destination_folder = '../Load'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Define the file names and paths
files = {
    'NPS_Cleaned_Data.csv': 'NPS_Cleaned_Data.csv',
    'NPS_Cleaned_Data.json': 'NPS_Cleaned_Data.json'
}

# Copy the file to the destination folder
for target_name, source_path in files.items():
    if os.path.exists(source_path):
        shutil.copy(source_path, os.path.join(destination_folder, target_name))

print(f"Files copied successfully to {destination_folder}: {os.listdir(destination_folder)}")
