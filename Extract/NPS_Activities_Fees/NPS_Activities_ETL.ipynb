# %%
# Dependencies
import json
import requests
import pandas as pd
from pprint import pprint
from config import NPS_API_KEY

# %%
# NPS API endpoint for activities
NPS_ACTIVITIES_URL = 'https://developer.nps.gov/api/v1/activities'
NPS_PARKS_BY_ACTIVITIES_URL = 'https://developer.nps.gov/api/v1/activities/parks'

# %%
# Build query URL
activities_query_url = f"{NPS_ACTIVITIES_URL}?api_key={NPS_API_KEY}"
activities_by_parks_query_url = f"{NPS_PARKS_BY_ACTIVITIES_URL}?api_key={NPS_API_KEY}"

# %%
# Fetch NPS activities data
activities_response = requests.get(activities_query_url)
activities_data = activities_response.json()

# Pretty-print the response
pprint(activities_data)
# Out:
# {'data': [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42',
#            'name': 'Arts and Culture'},
#           {'id': '13A57703-BB1A-41A2-94B8-53B692EB7238', 'name': 'Astronomy'},
#           {'id': '5F723BAD-7359-48FC-98FA-631592256E35',
#            'name': 'Auto and ATV'},
#           {'id': '7CE6E935-F839-4FEC-A63E-052B1DEF39D2', 'name': 'Biking'},
#           {'id': '071BA73C-1D3C-46D4-A53C-00D5602F7F0E', 'name': 'Boating'},
#           {'id': 'A59947B7-3376-49B4-AD02-C0423E08C5F7', 'name': 'Camping'},
#           {'id': '07CBCA6A-46B8-413F-8B6C-ABEDEBF9853E',
#            'name': 'Canyoneering'},
#           {'id': 'BA316D0F-92AE-4E00-8C80-DBD605DC58C3', 'name': 'Caving'},
#           {'id': 'B12FAAB9-713F-4B38-83E4-A273F5A43C77', 'name': 'Climbing'},
#           {'id': 'C11D3746-5063-4BD0-B245-7178D1AD866C',
#            'name': 'Compass and GPS'},
#           {'id': '8C495067-8E94-4D78-BBD4-3379DACF6550',
#            'name': 'Dog Sledding'},
#           {'id': 'AE42B46C-E4B7-4889-A122-08FE180371AE', 'name': 'Fishing'},
#           {'id': 'D72206E4-6CD1-4441-A355-F8F1827466B1', 'name': 'Flying'},
#           {'id': '1DFACD97-1B9C-4F5A-80F2-05593604799E', 'name': 'Food'},
#           {'id': '3F3ABD16-2C52-4EAA-A1F6-4235DE5686F0', 'name': 'Golfing'},
#           {'id': 'B33DC9B6-0B7D-4322-BAD7-A13A34C584A3',
#            'name': 'Guided Tours'},
#           {'id': '42FD78B9-2B90-4AA9-BC43-F10E9FEA8B5A', 'name': 'Hands-On'},
#           {'id': 'BFF8C027-7C8F-480B-A5F8-CD8CE490BFBA', 'name': 'Hiking'},
#           {'id': '0307955A-B65C-4CE4-A780-EB36BAAADF0B',
#            'name': 'Horse Trekking'},
#           {'id': '8386EEAF-985F-4DE8-9037-CCF91975AC94',
#            'name': 'Hunting and Gathering'},
#           {'id': '5FF5B286-E9C3-430E-B612-3380D8138600', 'name': 'Ice Skating'},
#           {'id': 'DF4A35E0-7983-4A3E-BC47-F37B872B0F25',
#            'name': 'Junior Ranger Program'},
#           {'id': 'B204DE60-5A24-43DD-8902-C81625A09A74',
#            'name': 'Living History'},
#           {'id': 'C8F98B28-3C10-41AE-AA99-092B3B398C43',
#            'name': 'Museum Exhibits'},
#           {'id': '4D224BCA-C127-408B-AC75-A51563C42411', 'name': 'Paddling'},
#           {'id': '0C0D142F-06B5-4BE1-8B44-491B90F93DEB', 'name': 'Park Film'},
#           {'id': '7779241F-A70B-49BC-86F0-829AE332C708', 'name': 'Playground'},
#           {'id': '42CF4021-8524-428E-866A-D33097A4A764',
#            'name': 'SCUBA Diving'},
#           {'id': '24380E3F-AD9D-4E38-BF13-C8EEB21893E7', 'name': 'Shopping'},
#           {'id': 'F9B1D433-6B86-4804-AED7-B50A519A3B7C', 'name': 'Skiing'},
#           {'id': '3EBF7EAC-68FC-4754-B6A4-0C38A1583D45', 'name': 'Snorkeling'},
#           {'id': 'C38B3C62-1BBF-4EA1-A1A2-35DE21B74C17', 'name': 'Snow Play'},
#           {'id': '7C912B83-1B1B-4807-9B66-97C12211E48E',
#            'name': 'Snowmobiling'},
#           {'id': '01D717BC-18BB-4FE4-95BA-6B13AD702038', 'name': 'Snowshoeing'},
#           {'id': 'AE3C95F5-E05B-4A28-81DD-1C5FD4BE88E2', 'name': 'Surfing'},
#           {'id': '587BB2D3-EC35-41B2-B3F7-A39E2B088AEE', 'name': 'Swimming'},
#           {'id': '94369BFD-F186-477E-8713-AE2A745154DA', 'name': 'Team Sports'},
#           {'id': '4D06CEED-90C6-4B69-B264-32CC90B69BA6', 'name': 'Tubing'},
#           {'id': '8A1C7B17-C2C6-4F7C-9539-EA1E19971D80',
#            'name': 'Water Skiing'},
#           {'id': '0B685688-3405-4E2A-ABBA-E3069492EC50',
#            'name': 'Wildlife Watching'}],
#  'limit': '50',
#  'start': '0',
#  'total': '40'}

# %%
# Fetch NPS activities by park data
activities_park_response = requests.get(activities_by_parks_query_url)
activities_park_data = activities_park_response.json()

# Pretty-print the response
pprint(activities_park_data)
# Out:
# {'data': [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42',
#            'name': 'Arts and Culture',
#            'parks': [{'designation': 'National Park',
#                       'fullName': 'Acadia National Park',
#                       'name': 'Acadia',
#                       'parkCode': 'acad',
#                       'states': 'ME',
#                       'url': 'https://www.nps.gov/acad/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'African Burial Ground National Monument',
#                       'name': 'African Burial Ground',
#                       'parkCode': 'afbg',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/afbg/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Agate Fossil Beds National Monument',
#                       'name': 'Agate Fossil Beds',
#                       'parkCode': 'agfo',
#                       'states': 'NE',
#                       'url': 'https://www.nps.gov/agfo/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Alibates Flint Quarries National Monument',
#                       'name': 'Alibates Flint Quarries',
#                       'parkCode': 'alfl',
#                       'states': 'TX',
#                       'url': 'https://www.nps.gov/alfl/index.htm'},
#                      {'designation': 'National Historic Trail',
#                       'fullName': 'Ala Kahakai National Historic Trail',
#                       'name': 'Ala Kahakai',
#                       'parkCode': 'alka',
#                       'states': 'HI',
#                       'url': 'https://www.nps.gov/alka/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Allegheny Portage Railroad National '
#                                   'Historic Site',
#                       'name': 'Allegheny Portage Railroad',
#                       'parkCode': 'alpo',
#                       'states': 'PA',
#                       'url': 'https://www.nps.gov/alpo/index.htm'},
#                      {'designation': 'Park',
#                       'fullName': 'American Memorial Park',
#                       'name': 'American Memorial',
#                       'parkCode': 'amme',
#                       'states': 'MP',
#                       'url': 'https://www.nps.gov/amme/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Andrew Johnson National Historic Site',
#                       'name': 'Andrew Johnson',
#                       'parkCode': 'anjo',
#                       'states': 'TN',
#                       'url': 'https://www.nps.gov/anjo/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Appomattox Court House National Historical '
#                                   'Park',
#                       'name': 'Appomattox Court House',
#                       'parkCode': 'apco',
#                       'states': 'VA',
#                       'url': 'https://www.nps.gov/apco/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Arches National Park',
#                       'name': 'Arches',
#                       'parkCode': 'arch',
#                       'states': 'UT',
#                       'url': 'https://www.nps.gov/arch/index.htm'},
#                      {'designation': 'National Memorial',
#                       'fullName': 'Arkansas Post National Memorial',
#                       'name': 'Arkansas Post',
#                       'parkCode': 'arpo',
#                       'states': 'AR',
#                       'url': 'https://www.nps.gov/arpo/index.htm'},
#                      {'designation': 'National Seashore',
#                       'fullName': 'Assateague Island National Seashore',
#                       'name': 'Assateague Island',
#                       'parkCode': 'asis',
#                       'states': 'MD,VA',
#                       'url': 'https://www.nps.gov/asis/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Aztec Ruins National Monument',
#                       'name': 'Aztec Ruins',
#                       'parkCode': 'azru',
#                       'states': 'NM',
#                       'url': 'https://www.nps.gov/azru/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Bandelier National Monument',
#                       'name': 'Bandelier',
#                       'parkCode': 'band',
#                       'states': 'NM',
#                       'url': 'https://www.nps.gov/band/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': "Bent's Old Fort National Historic Site",
#                       'name': "Bent's Old Fort",
#                       'parkCode': 'beol',
#                       'states': 'CO',
#                       'url': 'https://www.nps.gov/beol/index.htm'},
#                      {'designation': 'National Recreation Area',
#                       'fullName': 'Bighorn Canyon National Recreation Area',
#                       'name': 'Bighorn Canyon',
#                       'parkCode': 'bica',
#                       'states': 'MT,WY',
#                       'url': 'https://www.nps.gov/bica/index.htm'},
#                      {'designation': 'National Preserve',
#                       'fullName': 'Big Cypress National Preserve',
#                       'name': 'Big Cypress',
#                       'parkCode': 'bicy',
#                       'states': 'FL',
#                       'url': 'https://www.nps.gov/bicy/index.htm'},
#                      {'designation': 'National Battlefield',
#                       'fullName': 'Big Hole National Battlefield',
#                       'name': 'Big Hole',
#                       'parkCode': 'biho',
#                       'states': 'MT',
#                       'url': 'https://www.nps.gov/biho/index.htm'},
#                      {'designation': 'National River & Recreation Area',
#                       'fullName': 'Big South Fork National River & Recreation '
#                                   'Area',
#                       'name': 'Big South Fork',
#                       'parkCode': 'biso',
#                       'states': 'KY,TN',
#                       'url': 'https://www.nps.gov/biso/index.htm'},
#                      {'designation': 'Parkway',
#                       'fullName': 'Blue Ridge Parkway',
#                       'name': 'Blue Ridge',
#                       'parkCode': 'blri',
#                       'states': 'NC,VA',
#                       'url': 'https://www.nps.gov/blri/index.htm'},
#                      {'designation': 'National Recreation Area',
#                       'fullName': 'Boston Harbor Islands National Recreation '
#                                   'Area',
#                       'name': 'Boston Harbor Islands',
#                       'parkCode': 'boha',
#                       'states': 'MA',
#                       'url': 'https://www.nps.gov/boha/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Booker T Washington National Monument',
#                       'name': 'Booker T Washington',
#                       'parkCode': 'bowa',
#                       'states': 'VA',
#                       'url': 'https://www.nps.gov/bowa/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Castle Clinton National Monument',
#                       'name': 'Castle Clinton',
#                       'parkCode': 'cacl',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/cacl/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Casa Grande Ruins National Monument',
#                       'name': 'Casa Grande Ruins',
#                       'parkCode': 'cagr',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/cagr/index.htm'},
#                      {'designation': '',
#                       'fullName': 'Capitol Hill Parks',
#                       'name': 'Capitol Hill Parks',
#                       'parkCode': 'cahi',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/cahi/index.htm'},
#                      {'designation': 'National Historic Trail',
#                       'fullName': 'Captain John Smith Chesapeake National '
#                                   'Historic Trail',
#                       'name': 'Captain John Smith Chesapeake',
#                       'parkCode': 'cajo',
#                       'states': 'VA,MD,DE,DC,PA,NY',
#                       'url': 'https://www.nps.gov/cajo/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Capitol Reef National Park',
#                       'name': 'Capitol Reef',
#                       'parkCode': 'care',
#                       'states': 'UT',
#                       'url': 'https://www.nps.gov/care/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Cane River Creole National Historical Park',
#                       'name': 'Cane River Creole',
#                       'parkCode': 'cari',
#                       'states': 'LA',
#                       'url': 'https://www.nps.gov/cari/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Carl Sandburg Home National Historic Site',
#                       'name': 'Carl Sandburg Home',
#                       'parkCode': 'carl',
#                       'states': 'NC',
#                       'url': 'https://www.nps.gov/carl/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Cedar Breaks National Monument',
#                       'name': 'Cedar Breaks',
#                       'parkCode': 'cebr',
#                       'states': 'UT',
#                       'url': 'https://www.nps.gov/cebr/index.htm'},
#                      {'designation': 'National Memorial',
#                       'fullName': 'Chamizal National Memorial',
#                       'name': 'Chamizal',
#                       'parkCode': 'cham',
#                       'states': 'TX',
#                       'url': 'https://www.nps.gov/cham/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Christiansted National Historic Site',
#                       'name': 'Christiansted',
#                       'parkCode': 'chri',
#                       'states': 'VI',
#                       'url': 'https://www.nps.gov/chri/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Little Rock Central High School National '
#                                   'Historic Site',
#                       'name': 'Little Rock Central High School',
#                       'parkCode': 'chsc',
#                       'states': 'AR',
#                       'url': 'https://www.nps.gov/chsc/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Colonial National Historical Park',
#                       'name': 'Colonial',
#                       'parkCode': 'colo',
#                       'states': 'VA',
#                       'url': 'https://www.nps.gov/colo/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Cuyahoga Valley National Park',
#                       'name': 'Cuyahoga Valley',
#                       'parkCode': 'cuva',
#                       'states': 'OH',
#                       'url': 'https://www.nps.gov/cuva/index.htm'},
#                      {'designation': '',
#                       'fullName': 'Civil War Defenses of Washington',
#                       'name': 'Civil War Defenses of Washington',
#                       'parkCode': 'cwdw',
#                       'states': 'DC,MD,VA',
#                       'url': 'https://www.nps.gov/cwdw/index.htm'},
#                      {'designation': 'National Park & Preserve',
#                       'fullName': 'Denali National Park & Preserve',
#                       'name': 'Denali',
#                       'parkCode': 'dena',
#                       'states': 'AK',
#                       'url': 'https://www.nps.gov/dena/index.htm'},
#                      {'designation': 'National Recreation Area',
#                       'fullName': 'Delaware Water Gap National Recreation Area',
#                       'name': 'Delaware Water Gap',
#                       'parkCode': 'dewa',
#                       'states': 'NJ,PA',
#                       'url': 'https://www.nps.gov/dewa/index.htm'},
#                      {'designation': 'National Historic Trail',
#                       'fullName': 'El Camino Real de Tierra Adentro National '
#                                   'Historic Trail',
#                       'name': 'El Camino Real de Tierra Adentro',
#                       'parkCode': 'elca',
#                       'states': 'NM,TX',
#                       'url': 'https://www.nps.gov/elca/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'El Malpais National Monument',
#                       'name': 'El Malpais',
#                       'parkCode': 'elma',
#                       'states': 'NM',
#                       'url': 'https://www.nps.gov/elma/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'El Morro National Monument',
#                       'name': 'El Morro',
#                       'parkCode': 'elmo',
#                       'states': 'NM',
#                       'url': 'https://www.nps.gov/elmo/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': "Eugene O'Neill National Historic Site",
#                       'name': "Eugene O'Neill",
#                       'parkCode': 'euon',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/euon/index.htm'},
#                      {'designation': 'National Memorial',
#                       'fullName': 'Federal Hall National Memorial',
#                       'name': 'Federal Hall',
#                       'parkCode': 'feha',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/feha/index.htm'},
#                      {'designation': 'National Seashore',
#                       'fullName': 'Fire Island National Seashore',
#                       'name': 'Fire Island',
#                       'parkCode': 'fiis',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/fiis/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Fort Davis National Historic Site',
#                       'name': 'Fort Davis',
#                       'parkCode': 'foda',
#                       'states': 'TX',
#                       'url': 'https://www.nps.gov/foda/index.htm'},
#                      {'designation': '',
#                       'fullName': 'Fort Dupont Park',
#                       'name': 'Fort Dupont Park',
#                       'parkCode': 'fodu',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/fodu/index.htm'},
#                      {'designation': 'National Monument and Historic Shrine',
#                       'fullName': 'Fort McHenry National Monument and Historic '
#                                   'Shrine',
#                       'name': 'Fort McHenry',
#                       'parkCode': 'fomc',
#                       'states': 'MD',
#                       'url': 'https://www.nps.gov/fomc/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Fort Point National Historic Site',
#                       'name': 'Fort Point',
#                       'parkCode': 'fopo',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/fopo/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Fort Raleigh National Historic Site',
#                       'name': 'Fort Raleigh',
#                       'parkCode': 'fora',
#                       'states': 'NC',
#                       'url': 'https://www.nps.gov/fora/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Fort Stanwix National Monument',
#                       'name': 'Fort Stanwix',
#                       'parkCode': 'fost',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/fost/index.htm'},
#                      {'designation': '',
#                       'fullName': "Ford's Theatre",
#                       'name': "Ford's Theatre",
#                       'parkCode': 'foth',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/foth/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Fort Vancouver National Historic Site',
#                       'name': 'Fort Vancouver',
#                       'parkCode': 'fova',
#                       'states': 'OR,WA',
#                       'url': 'https://www.nps.gov/fova/index.htm'},
#                      {'designation': 'National Military Park',
#                       'fullName': 'Gettysburg National Military Park',
#                       'name': 'Gettysburg',
#                       'parkCode': 'gett',
#                       'states': 'PA',
#                       'url': 'https://www.nps.gov/gett/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'George Washington Birthplace National '
#                                   'Monument',
#                       'name': 'George Washington Birthplace',
#                       'parkCode': 'gewa',
#                       'states': 'VA',
#                       'url': 'https://www.nps.gov/gewa/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Glacier National Park',
#                       'name': 'Glacier',
#                       'parkCode': 'glac',
#                       'states': 'MT',
#                       'url': 'https://www.nps.gov/glac/index.htm'},
#                      {'designation': 'National Park & Preserve',
#                       'fullName': 'Glacier Bay National Park & Preserve',
#                       'name': 'Glacier Bay',
#                       'parkCode': 'glba',
#                       'states': 'AK',
#                       'url': 'https://www.nps.gov/glba/index.htm'},
#                      {'designation': 'Park',
#                       'fullName': 'Glen Echo Park',
#                       'name': 'Glen Echo',
#                       'parkCode': 'glec',
#                       'states': 'MD',
#                       'url': 'https://www.nps.gov/glec/index.htm'},
#                      {'designation': 'National Recreation Area',
#                       'fullName': 'Golden Gate National Recreation Area',
#                       'name': 'Golden Gate',
#                       'parkCode': 'goga',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/goga/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Grand Canyon National Park',
#                       'name': 'Grand Canyon',
#                       'parkCode': 'grca',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/grca/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Grant-Kohrs Ranch National Historic Site',
#                       'name': 'Grant-Kohrs Ranch',
#                       'parkCode': 'grko',
#                       'states': 'MT',
#                       'url': 'https://www.nps.gov/grko/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Grand Portage National Monument',
#                       'name': 'Grand Portage',
#                       'parkCode': 'grpo',
#                       'states': 'MN',
#                       'url': 'https://www.nps.gov/grpo/index.htm'},
#                      {'designation': 'National Park & Preserve',
#                       'fullName': 'Great Sand Dunes National Park & Preserve',
#                       'name': 'Great Sand Dunes',
#                       'parkCode': 'grsa',
#                       'states': 'CO',
#                       'url': 'https://www.nps.gov/grsa/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Great Smoky Mountains National Park',
#                       'name': 'Great Smoky Mountains',
#                       'parkCode': 'grsm',
#                       'states': 'NC,TN',
#                       'url': 'https://www.nps.gov/grsm/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Grand Teton National Park',
#                       'name': 'Grand Teton',
#                       'parkCode': 'grte',
#                       'states': 'WY',
#                       'url': 'https://www.nps.gov/grte/index.htm'},
#                      {'designation': 'National Military Park',
#                       'fullName': 'Guilford Courthouse National Military Park',
#                       'name': 'Guilford Courthouse',
#                       'parkCode': 'guco',
#                       'states': 'NC',
#                       'url': 'https://www.nps.gov/guco/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'George Washington Carver National Monument',
#                       'name': 'George Washington Carver',
#                       'parkCode': 'gwca',
#                       'states': 'MO',
#                       'url': 'https://www.nps.gov/gwca/index.htm'},
#                      {'designation': 'Memorial Parkway',
#                       'fullName': 'George Washington Memorial Parkway',
#                       'name': 'George Washington',
#                       'parkCode': 'gwmp',
#                       'states': 'DC,MD,VA',
#                       'url': 'https://www.nps.gov/gwmp/index.htm'},
#                      {'designation': 'National Memorial',
#                       'fullName': 'Hamilton Grange National Memorial',
#                       'name': 'Hamilton Grange',
#                       'parkCode': 'hagr',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/hagr/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Hampton National Historic Site',
#                       'name': 'Hampton',
#                       'parkCode': 'hamp',
#                       'states': 'MD',
#                       'url': 'https://www.nps.gov/hamp/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Hawaiʻi Volcanoes National Park',
#                       'name': 'Hawaiʻi Volcanoes',
#                       'parkCode': 'havo',
#                       'states': 'HI',
#                       'url': 'https://www.nps.gov/havo/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Herbert Hoover National Historic Site',
#                       'name': 'Herbert Hoover',
#                       'parkCode': 'heho',
#                       'states': 'IA',
#                       'url': 'https://www.nps.gov/heho/index.htm'},
#                      {'designation': 'National Military Park',
#                       'fullName': 'Horseshoe Bend National Military Park',
#                       'name': 'Horseshoe Bend',
#                       'parkCode': 'hobe',
#                       'states': 'AL',
#                       'url': 'https://www.nps.gov/hobe/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Hopewell Culture National Historical Park',
#                       'name': 'Hopewell Culture',
#                       'parkCode': 'hocu',
#                       'states': 'OH',
#                       'url': 'https://www.nps.gov/hocu/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Hopewell Furnace National Historic Site',
#                       'name': 'Hopewell Furnace',
#                       'parkCode': 'hofu',
#                       'states': 'PA',
#                       'url': 'https://www.nps.gov/hofu/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Homestead National Historical Park',
#                       'name': 'Homestead',
#                       'parkCode': 'home',
#                       'states': 'NE',
#                       'url': 'https://www.nps.gov/home/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Hubbell Trading Post National Historic Site',
#                       'name': 'Hubbell Trading Post',
#                       'parkCode': 'hutr',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/hutr/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Indiana Dunes National Park',
#                       'name': 'Indiana Dunes',
#                       'parkCode': 'indu',
#                       'states': 'IN',
#                       'url': 'https://www.nps.gov/indu/index.htm'},
#                      {'designation': '',
#                       'fullName': 'Iñupiat Heritage Center',
#                       'name': 'Iñupiat Heritage Center',
#                       'parkCode': 'inup',
#                       'states': 'AK',
#                       'url': 'https://www.nps.gov/inup/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Isle Royale National Park',
#                       'name': 'Isle Royale',
#                       'parkCode': 'isro',
#                       'states': 'MI',
#                       'url': 'https://www.nps.gov/isro/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'New Orleans Jazz National Historical Park',
#                       'name': 'New Orleans Jazz',
#                       'parkCode': 'jazz',
#                       'states': 'LA',
#                       'url': 'https://www.nps.gov/jazz/index.htm'},
#                      {'designation': 'National Historical Park and Preserve',
#                       'fullName': 'Jean Lafitte National Historical Park and '
#                                   'Preserve',
#                       'name': 'Jean Lafitte',
#                       'parkCode': 'jela',
#                       'states': 'LA',
#                       'url': 'https://www.nps.gov/jela/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Kaloko-Honokōhau National Historical Park',
#                       'name': 'Kaloko-Honokōhau',
#                       'parkCode': 'kaho',
#                       'states': 'HI',
#                       'url': 'https://www.nps.gov/kaho/index.htm'},
#                      {'designation': '',
#                       'fullName': 'Kenilworth Park & Aquatic Gardens',
#                       'name': 'Kenilworth Park & Aquatic Gardens',
#                       'parkCode': 'keaq',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/keaq/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Klondike Gold Rush National Historical Park',
#                       'name': 'Klondike Gold Rush',
#                       'parkCode': 'klgo',
#                       'states': 'AK',
#                       'url': 'https://www.nps.gov/klgo/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Knife River Indian Villages National '
#                                   'Historic Site',
#                       'name': 'Knife River Indian Villages',
#                       'parkCode': 'knri',
#                       'states': 'ND',
#                       'url': 'https://www.nps.gov/knri/index.htm'},
#                      {'designation': 'National Memorial',
#                       'fullName': 'Lincoln Boyhood National Memorial',
#                       'name': 'Lincoln Boyhood',
#                       'parkCode': 'libo',
#                       'states': 'IN',
#                       'url': 'https://www.nps.gov/libo/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Lincoln Home National Historic Site',
#                       'name': 'Lincoln Home',
#                       'parkCode': 'liho',
#                       'states': 'IL',
#                       'url': 'https://www.nps.gov/liho/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Lower East Side Tenement Museum National '
#                                   'Historic Site',
#                       'name': 'Lower East Side Tenement Museum',
#                       'parkCode': 'loea',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/loea/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': "Longfellow House Washington's Headquarters "
#                                   'National Historic Site',
#                       'name': "Longfellow House Washington's Headquarters",
#                       'parkCode': 'long',
#                       'states': 'MA',
#                       'url': 'https://www.nps.gov/long/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Lowell National Historical Park',
#                       'name': 'Lowell',
#                       'parkCode': 'lowe',
#                       'states': 'MA',
#                       'url': 'https://www.nps.gov/lowe/index.htm'},
#                      {'designation': '',
#                       'fullName': 'Maine Acadian Culture',
#                       'name': 'Maine Acadian Culture',
#                       'parkCode': 'maac',
#                       'states': 'ME',
#                       'url': 'https://www.nps.gov/maac/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Marsh - Billings - Rockefeller National '
#                                   'Historical Park',
#                       'name': 'Marsh - Billings - Rockefeller',
#                       'parkCode': 'mabi',
#                       'states': 'VT',
#                       'url': 'https://www.nps.gov/mabi/index.htm'},
#                      {'designation': '',
#                       'fullName': '**********National Mall**********',
#                       'name': '**********National Mall**********',
#                       'parkCode': 'mall',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/mall/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Martin Luther King, Jr. National Historical '
#                                   'Park',
#                       'name': 'Martin Luther King, Jr.',
#                       'parkCode': 'malu',
#                       'states': 'GA',
#                       'url': 'https://www.nps.gov/malu/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Martin Van Buren National Historic Site',
#                       'name': 'Martin Van Buren',
#                       'parkCode': 'mava',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/mava/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Montezuma Castle National Monument',
#                       'name': 'Montezuma Castle',
#                       'parkCode': 'moca',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/moca/index.htm'},
#                      {'designation': 'National Battlefield',
#                       'fullName': 'Moores Creek National Battlefield',
#                       'name': 'Moores Creek',
#                       'parkCode': 'mocr',
#                       'states': 'NC',
#                       'url': 'https://www.nps.gov/mocr/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Morristown National Historical Park',
#                       'name': 'Morristown',
#                       'parkCode': 'morr',
#                       'states': 'NJ',
#                       'url': 'https://www.nps.gov/morr/index.htm'},
#                      {'designation': '',
#                       'fullName': 'National Mall and Memorial Parks',
#                       'name': 'National Mall and Memorial Parks',
#                       'parkCode': 'nama',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/nama/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Navajo National Monument',
#                       'name': 'Navajo',
#                       'parkCode': 'nava',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/nava/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Nez Perce National Historical Park',
#                       'name': 'Nez Perce',
#                       'parkCode': 'nepe',
#                       'states': 'ID,MT,OR,WA',
#                       'url': 'https://www.nps.gov/nepe/index.htm'},
#                      {'designation': 'National Park & Preserve',
#                       'fullName': 'New River Gorge National Park & Preserve',
#                       'name': 'New River Gorge',
#                       'parkCode': 'neri',
#                       'states': 'WV',
#                       'url': 'https://www.nps.gov/neri/index.htm'},
#                      {'designation': '',
#                       'fullName': 'National Parks of New York Harbor',
#                       'name': 'National Parks of New York Harbor',
#                       'parkCode': 'npnh',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/npnh/index.htm'},
#                      {'designation': '',
#                       'fullName': 'National Park of American Samoa',
#                       'name': 'National Park of American Samoa',
#                       'parkCode': 'npsa',
#                       'states': 'AS',
#                       'url': 'https://www.nps.gov/npsa/index.htm'},
#                      {'designation': 'National Historic Trail',
#                       'fullName': 'Old Spanish National Historic Trail',
#                       'name': 'Old Spanish',
#                       'parkCode': 'olsp',
#                       'states': 'AZ,CA,CO,NV,NM,UT',
#                       'url': 'https://www.nps.gov/olsp/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Palo Alto Battlefield National Historical '
#                                   'Park',
#                       'name': 'Palo Alto Battlefield',
#                       'parkCode': 'paal',
#                       'states': 'TX',
#                       'url': 'https://www.nps.gov/paal/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Paterson Great Falls National Historical '
#                                   'Park',
#                       'name': 'Paterson Great Falls',
#                       'parkCode': 'pagr',
#                       'states': 'NJ',
#                       'url': 'https://www.nps.gov/pagr/index.htm'},
#                      {'designation': 'National Seashore',
#                       'fullName': 'Padre Island National Seashore',
#                       'name': 'Padre Island',
#                       'parkCode': 'pais',
#                       'states': 'TX',
#                       'url': 'https://www.nps.gov/pais/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Pecos National Historical Park',
#                       'name': 'Pecos',
#                       'parkCode': 'peco',
#                       'states': 'NM',
#                       'url': 'https://www.nps.gov/peco/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Petrified Forest National Park',
#                       'name': 'Petrified Forest',
#                       'parkCode': 'pefo',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/pefo/index.htm'},
#                      {'designation': 'Memorial',
#                       'fullName': "Perry's Victory & International Peace "
#                                   'Memorial',
#                       'name': "Perry's Victory & International Peace",
#                       'parkCode': 'pevi',
#                       'states': 'OH',
#                       'url': 'https://www.nps.gov/pevi/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Pipestone National Monument',
#                       'name': 'Pipestone',
#                       'parkCode': 'pipe',
#                       'states': 'MN',
#                       'url': 'https://www.nps.gov/pipe/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Pipe Spring National Monument',
#                       'name': 'Pipe Spring',
#                       'parkCode': 'pisp',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/pisp/index.htm'},
#                      {'designation': '',
#                       'fullName': 'Presidio of San Francisco',
#                       'name': 'Presidio of San Francisco',
#                       'parkCode': 'prsf',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/prsf/index.htm'},
#                      {'designation': 'Park',
#                       'fullName': 'Prince William Forest Park',
#                       'name': 'Prince William Forest',
#                       'parkCode': 'prwi',
#                       'states': 'VA',
#                       'url': 'https://www.nps.gov/prwi/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Puʻukoholā Heiau National Historic Site',
#                       'name': 'Puʻukoholā Heiau',
#                       'parkCode': 'puhe',
#                       'states': 'HI',
#                       'url': 'https://www.nps.gov/puhe/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Puʻuhonua o Hōnaunau National Historical '
#                                   'Park',
#                       'name': 'Puʻuhonua o Hōnaunau',
#                       'parkCode': 'puho',
#                       'states': 'HI',
#                       'url': 'https://www.nps.gov/puho/index.htm'},
#                      {'designation': 'National and State Parks',
#                       'fullName': 'Redwood National and State Parks',
#                       'name': 'Redwood',
#                       'parkCode': 'redw',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/redw/index.htm'},
#                      {'designation': 'National Battlefield Park',
#                       'fullName': 'River Raisin National Battlefield Park',
#                       'name': 'River Raisin',
#                       'parkCode': 'rira',
#                       'states': 'MI',
#                       'url': 'https://www.nps.gov/rira/index.htm'},
#                      {'designation': 'Park',
#                       'fullName': 'Rock Creek Park',
#                       'name': 'Rock Creek',
#                       'parkCode': 'rocr',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/rocr/index.htm'},
#                      {'designation': 'National Memorial',
#                       'fullName': 'Roger Williams National Memorial',
#                       'name': 'Roger Williams',
#                       'parkCode': 'rowi',
#                       'states': 'RI',
#                       'url': 'https://www.nps.gov/rowi/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'San Antonio Missions National Historical '
#                                   'Park',
#                       'name': 'San Antonio Missions',
#                       'parkCode': 'saan',
#                       'states': 'TX',
#                       'url': 'https://www.nps.gov/saan/index.htm'},
#                      {'designation': 'National Historic Trail',
#                       'fullName': 'Santa Fe National Historic Trail',
#                       'name': 'Santa Fe',
#                       'parkCode': 'safe',
#                       'states': 'CO,KS,MO,NM,OK',
#                       'url': 'https://www.nps.gov/safe/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'San Francisco Maritime National Historical '
#                                   'Park',
#                       'name': 'San Francisco Maritime',
#                       'parkCode': 'safr',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/safr/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Saint-Gaudens National Historical Park',
#                       'name': 'Saint-Gaudens',
#                       'parkCode': 'saga',
#                       'states': 'NH',
#                       'url': 'https://www.nps.gov/saga/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Saguaro National Park',
#                       'name': 'Saguaro',
#                       'parkCode': 'sagu',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/sagu/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Sagamore Hill National Historic Site',
#                       'name': 'Sagamore Hill',
#                       'parkCode': 'sahi',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/sahi/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'San Juan Island National Historical Park',
#                       'name': 'San Juan Island',
#                       'parkCode': 'sajh',
#                       'states': 'WA',
#                       'url': 'https://www.nps.gov/sajh/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'San Juan National Historic Site',
#                       'name': 'San Juan',
#                       'parkCode': 'saju',
#                       'states': 'PR',
#                       'url': 'https://www.nps.gov/saju/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': "Saint Paul's Church National Historic Site",
#                       'name': "Saint Paul's Church",
#                       'parkCode': 'sapa',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/sapa/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Saratoga National Historical Park',
#                       'name': 'Saratoga',
#                       'parkCode': 'sara',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/sara/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Scotts Bluff National Monument',
#                       'name': 'Scotts Bluff',
#                       'parkCode': 'scbl',
#                       'states': 'NE',
#                       'url': 'https://www.nps.gov/scbl/index.htm'},
#                      {'designation': 'National Military Park',
#                       'fullName': 'Shiloh National Military Park',
#                       'name': 'Shiloh',
#                       'parkCode': 'shil',
#                       'states': 'TN,MS',
#                       'url': 'https://www.nps.gov/shil/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Sitka National Historical Park',
#                       'name': 'Sitka',
#                       'parkCode': 'sitk',
#                       'states': 'AK',
#                       'url': 'https://www.nps.gov/sitk/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Ste. Geneviève National Historical Park',
#                       'name': 'Ste. Geneviève',
#                       'parkCode': 'stge',
#                       'states': 'MO',
#                       'url': 'https://www.nps.gov/stge/index.htm'},
#                      {'designation': 'National Battlefield',
#                       'fullName': 'Stones River National Battlefield',
#                       'name': 'Stones River',
#                       'parkCode': 'stri',
#                       'states': 'TN',
#                       'url': 'https://www.nps.gov/stri/index.htm'},
#                      {'designation': 'National Historic Trail',
#                       'fullName': 'Star-Spangled Banner National Historic '
#                                   'Trail',
#                       'name': 'Star-Spangled Banner',
#                       'parkCode': 'stsp',
#                       'states': 'DC,MD,VA',
#                       'url': 'https://www.nps.gov/stsp/index.htm'},
#                      {'designation': 'National Preserve',
#                       'fullName': 'Tallgrass Prairie National Preserve',
#                       'name': 'Tallgrass Prairie',
#                       'parkCode': 'tapr',
#                       'states': 'KS',
#                       'url': 'https://www.nps.gov/tapr/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Thomas Cole National Historic Site',
#                       'name': 'Thomas Cole',
#                       'parkCode': 'thco',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/thco/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Theodore Roosevelt Inaugural National '
#                                   'Historic Site',
#                       'name': 'Theodore Roosevelt Inaugural',
#                       'parkCode': 'thri',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/thri/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Emmett Till and Mamie Till-Mobley National '
#                                   'Monument',
#                       'name': 'Emmett Till and Mamie Till-Mobley',
#                       'parkCode': 'till',
#                       'states': 'IL,MS',
#                       'url': 'https://www.nps.gov/till/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Touro Synagogue National Historic Site',
#                       'name': 'Touro Synagogue',
#                       'parkCode': 'tosy',
#                       'states': 'RI',
#                       'url': 'https://www.nps.gov/tosy/index.htm'},
# ...
#                      {'designation': 'National and State Parks',
#                       'fullName': 'Redwood National and State Parks',
#                       'name': 'Redwood',
#                       'parkCode': 'redw',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/redw/index.htm'},
#                      {'designation': 'Wild & Scenic River',
#                       'fullName': 'Rio Grande Wild & Scenic River',
#                       'name': 'Rio Grande',
#                       'parkCode': 'rigr',
#                       'states': 'TX',
#                       'url': 'https://www.nps.gov/rigr/index.htm'},
#                      {'designation': 'National Battlefield Park',
#                       'fullName': 'River Raisin National Battlefield Park',
#                       'name': 'River Raisin',
#                       'parkCode': 'rira',
#                       'states': 'MI',
#                       'url': 'https://www.nps.gov/rira/index.htm'},
#                      {'designation': 'Park',
#                       'fullName': 'Rock Creek Park',
#                       'name': 'Rock Creek',
#                       'parkCode': 'rocr',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/rocr/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Rocky Mountain National Park',
#                       'name': 'Rocky Mountain',
#                       'parkCode': 'romo',
#                       'states': 'CO',
#                       'url': 'https://www.nps.gov/romo/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Russell Cave National Monument',
#                       'name': 'Russell Cave',
#                       'parkCode': 'ruca',
#                       'states': 'AL',
#                       'url': 'https://www.nps.gov/ruca/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'San Antonio Missions National Historical '
#                                   'Park',
#                       'name': 'San Antonio Missions',
#                       'parkCode': 'saan',
#                       'states': 'TX',
#                       'url': 'https://www.nps.gov/saan/index.htm'},
#                      {'designation': 'National Scenic Riverway',
#                       'fullName': 'Saint Croix National Scenic Riverway',
#                       'name': 'Saint Croix',
#                       'parkCode': 'sacn',
#                       'states': 'WI,MN',
#                       'url': 'https://www.nps.gov/sacn/index.htm'},
#                      {'designation': 'International Historic Site',
#                       'fullName': 'Saint Croix Island International Historic '
#                                   'Site',
#                       'name': 'Saint Croix Island',
#                       'parkCode': 'sacr',
#                       'states': 'ME',
#                       'url': 'https://www.nps.gov/sacr/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Saint-Gaudens National Historical Park',
#                       'name': 'Saint-Gaudens',
#                       'parkCode': 'saga',
#                       'states': 'NH',
#                       'url': 'https://www.nps.gov/saga/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Sagamore Hill National Historic Site',
#                       'name': 'Sagamore Hill',
#                       'parkCode': 'sahi',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/sahi/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'San Juan Island National Historical Park',
#                       'name': 'San Juan Island',
#                       'parkCode': 'sajh',
#                       'states': 'WA',
#                       'url': 'https://www.nps.gov/sajh/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'San Juan National Historic Site',
#                       'name': 'San Juan',
#                       'parkCode': 'saju',
#                       'states': 'PR',
#                       'url': 'https://www.nps.gov/saju/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Sand Creek Massacre National Historic Site',
#                       'name': 'Sand Creek Massacre',
#                       'parkCode': 'sand',
#                       'states': 'CO',
#                       'url': 'https://www.nps.gov/sand/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Salinas Pueblo Missions National Monument',
#                       'name': 'Salinas Pueblo Missions',
#                       'parkCode': 'sapu',
#                       'states': 'NM',
#                       'url': 'https://www.nps.gov/sapu/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Saratoga National Historical Park',
#                       'name': 'Saratoga',
#                       'parkCode': 'sara',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/sara/index.htm'},
#                      {'designation': 'National Parks',
#                       'fullName': 'Sequoia & Kings Canyon National Parks',
#                       'name': 'Sequoia & Kings Canyon',
#                       'parkCode': 'seki',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/seki/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Shenandoah National Park',
#                       'name': 'Shenandoah',
#                       'parkCode': 'shen',
#                       'states': 'VA',
#                       'url': 'https://www.nps.gov/shen/index.htm'},
#                      {'designation': 'National Military Park',
#                       'fullName': 'Shiloh National Military Park',
#                       'name': 'Shiloh',
#                       'parkCode': 'shil',
#                       'states': 'TN,MS',
#                       'url': 'https://www.nps.gov/shil/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Sitka National Historical Park',
#                       'name': 'Sitka',
#                       'parkCode': 'sitk',
#                       'states': 'AK',
#                       'url': 'https://www.nps.gov/sitk/index.htm'},
#                      {'designation': 'National Battlefield',
#                       'fullName': 'Stones River National Battlefield',
#                       'name': 'Stones River',
#                       'parkCode': 'stri',
#                       'states': 'TN',
#                       'url': 'https://www.nps.gov/stri/index.htm'},
#                      {'designation': 'National Preserve',
#                       'fullName': 'Tallgrass Prairie National Preserve',
#                       'name': 'Tallgrass Prairie',
#                       'parkCode': 'tapr',
#                       'states': 'KS',
#                       'url': 'https://www.nps.gov/tapr/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Thomas Cole National Historic Site',
#                       'name': 'Thomas Cole',
#                       'parkCode': 'thco',
#                       'states': 'NY',
#                       'url': 'https://www.nps.gov/thco/index.htm'},
#                      {'designation': '',
#                       'fullName': 'Theodore Roosevelt Island',
#                       'name': 'Theodore Roosevelt Island',
#                       'parkCode': 'this',
#                       'states': 'DC',
#                       'url': 'https://www.nps.gov/this/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Theodore Roosevelt National Park',
#                       'name': 'Theodore Roosevelt',
#                       'parkCode': 'thro',
#                       'states': 'ND',
#                       'url': 'https://www.nps.gov/thro/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Thomas Stone National Historic Site',
#                       'name': 'Thomas Stone',
#                       'parkCode': 'thst',
#                       'states': 'MD',
#                       'url': 'https://www.nps.gov/thst/index.htm'},
#                      {'designation': 'Ecological & Historic Preserve',
#                       'fullName': 'Timucuan Ecological & Historic Preserve',
#                       'name': 'Timucuan',
#                       'parkCode': 'timu',
#                       'states': 'FL',
#                       'url': 'https://www.nps.gov/timu/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Tumacácori National Historical Park',
#                       'name': 'Tumacácori',
#                       'parkCode': 'tuma',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/tuma/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Tule Springs Fossil Beds National Monument',
#                       'name': 'Tule Springs Fossil Beds',
#                       'parkCode': 'tusk',
#                       'states': '',
#                       'url': 'https://www.nps.gov/tusk/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Tuzigoot National Monument',
#                       'name': 'Tuzigoot',
#                       'parkCode': 'tuzi',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/tuzi/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Ulysses S Grant National Historic Site',
#                       'name': 'Ulysses S Grant',
#                       'parkCode': 'ulsg',
#                       'states': 'MO',
#                       'url': 'https://www.nps.gov/ulsg/index.htm'},
#                      {'designation': 'Scenic & Recreational River',
#                       'fullName': 'Upper Delaware Scenic & Recreational River',
#                       'name': 'Upper Delaware',
#                       'parkCode': 'upde',
#                       'states': 'NY,PA',
#                       'url': 'https://www.nps.gov/upde/index.htm'},
#                      {'designation': 'National Historical Park',
#                       'fullName': 'Valley Forge National Historical Park',
#                       'name': 'Valley Forge',
#                       'parkCode': 'vafo',
#                       'states': 'PA',
#                       'url': 'https://www.nps.gov/vafo/index.htm'},
#                      {'designation': 'National Preserve',
#                       'fullName': 'Valles Caldera National Preserve',
#                       'name': 'Valles Caldera',
#                       'parkCode': 'vall',
#                       'states': 'NM',
#                       'url': 'https://www.nps.gov/vall/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Virgin Islands Coral Reef National Monument',
#                       'name': 'Virgin Islands Coral Reef',
#                       'parkCode': 'vicr',
#                       'states': 'VI',
#                       'url': 'https://www.nps.gov/vicr/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Virgin Islands National Park',
#                       'name': 'Virgin Islands',
#                       'parkCode': 'viis',
#                       'states': 'VI',
#                       'url': 'https://www.nps.gov/viis/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Voyageurs National Park',
#                       'name': 'Voyageurs',
#                       'parkCode': 'voya',
#                       'states': 'MN',
#                       'url': 'https://www.nps.gov/voya/index.htm'},
#                      {'designation': 'National Recreation Area',
#                       'fullName': 'Whiskeytown National Recreation Area',
#                       'name': 'Whiskeytown',
#                       'parkCode': 'whis',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/whis/index.htm'},
#                      {'designation': 'National Historic Site',
#                       'fullName': 'Whitman Mission National Historic Site',
#                       'name': 'Whitman Mission',
#                       'parkCode': 'whmi',
#                       'states': 'WA',
#                       'url': 'https://www.nps.gov/whmi/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Wind Cave National Park',
#                       'name': 'Wind Cave',
#                       'parkCode': 'wica',
#                       'states': 'SD',
#                       'url': 'https://www.nps.gov/wica/index.htm'},
#                      {'designation': 'National Battlefield',
#                       'fullName': "Wilson's Creek National Battlefield",
#                       'name': "Wilson's Creek",
#                       'parkCode': 'wicr',
#                       'states': 'MO',
#                       'url': 'https://www.nps.gov/wicr/index.htm'},
#                      {'designation': 'National Park & Preserve',
#                       'fullName': 'Wrangell - St Elias National Park & '
#                                   'Preserve',
#                       'name': 'Wrangell - St Elias',
#                       'parkCode': 'wrst',
#                       'states': 'AK',
#                       'url': 'https://www.nps.gov/wrst/index.htm'},
#                      {'designation': 'National Monument',
#                       'fullName': 'Wupatki National Monument',
#                       'name': 'Wupatki',
#                       'parkCode': 'wupa',
#                       'states': 'AZ',
#                       'url': 'https://www.nps.gov/wupa/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Yellowstone National Park',
#                       'name': 'Yellowstone',
#                       'parkCode': 'yell',
#                       'states': 'ID,MT,WY',
#                       'url': 'https://www.nps.gov/yell/index.htm'},
#                      {'designation': 'Part of Colonial National Historical '
#                                      'Park',
#                       'fullName': 'Yorktown Battlefield Part of Colonial '
#                                   'National Historical Park',
#                       'name': 'Yorktown Battlefield',
#                       'parkCode': 'york',
#                       'states': 'VA',
#                       'url': 'https://www.nps.gov/york/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Yosemite National Park',
#                       'name': 'Yosemite',
#                       'parkCode': 'yose',
#                       'states': 'CA',
#                       'url': 'https://www.nps.gov/yose/index.htm'},
#                      {'designation': 'National Preserve',
#                       'fullName': 'Yukon - Charley Rivers National Preserve',
#                       'name': 'Yukon - Charley Rivers',
#                       'parkCode': 'yuch',
#                       'states': 'AK',
#                       'url': 'https://www.nps.gov/yuch/index.htm'},
#                      {'designation': 'National Park',
#                       'fullName': 'Zion National Park',
#                       'name': 'Zion',
#                       'parkCode': 'zion',
#                       'states': 'UT',
#                       'url': 'https://www.nps.gov/zion/index.htm'}]}],
#  'limit': '50',
#  'start': '0',
#  'total': '40'}

# %%
# Function to transform activities data into a DataFrame
def transform_activities_to_df(data):
    transformed_data = []
    for item in data['data']:
        transformed_data.append({
            'activity_id': item['id'],
            'activity_name': item['name']
        })
    activities_df = pd.DataFrame(transformed_data)
    return activities_df

# Transform activities data into a DataFrame
activities_df = transform_activities_to_df(activities_data)

# Pretty-print the transformed activities DataFrame
print("Transformed Activities DataFrame:")
activities_df
# Out:
# Transformed Activities DataFrame:
#                              activity_id          activity_name
# 0   09DF0950-D319-4557-A57E-04CD2F63FF42       Arts and Culture
# 1   13A57703-BB1A-41A2-94B8-53B692EB7238              Astronomy
# 2   5F723BAD-7359-48FC-98FA-631592256E35           Auto and ATV
# 3   7CE6E935-F839-4FEC-A63E-052B1DEF39D2                 Biking
# 4   071BA73C-1D3C-46D4-A53C-00D5602F7F0E                Boating
# 5   A59947B7-3376-49B4-AD02-C0423E08C5F7                Camping
# 6   07CBCA6A-46B8-413F-8B6C-ABEDEBF9853E           Canyoneering
# 7   BA316D0F-92AE-4E00-8C80-DBD605DC58C3                 Caving
# 8   B12FAAB9-713F-4B38-83E4-A273F5A43C77               Climbing
# 9   C11D3746-5063-4BD0-B245-7178D1AD866C        Compass and GPS
# 10  8C495067-8E94-4D78-BBD4-3379DACF6550           Dog Sledding
# 11  AE42B46C-E4B7-4889-A122-08FE180371AE                Fishing
# 12  D72206E4-6CD1-4441-A355-F8F1827466B1                 Flying
# 13  1DFACD97-1B9C-4F5A-80F2-05593604799E                   Food
# 14  3F3ABD16-2C52-4EAA-A1F6-4235DE5686F0                Golfing
# 15  B33DC9B6-0B7D-4322-BAD7-A13A34C584A3           Guided Tours
# 16  42FD78B9-2B90-4AA9-BC43-F10E9FEA8B5A               Hands-On
# 17  BFF8C027-7C8F-480B-A5F8-CD8CE490BFBA                 Hiking
# 18  0307955A-B65C-4CE4-A780-EB36BAAADF0B         Horse Trekking
# 19  8386EEAF-985F-4DE8-9037-CCF91975AC94  Hunting and Gathering
# 20  5FF5B286-E9C3-430E-B612-3380D8138600            Ice Skating
# 21  DF4A35E0-7983-4A3E-BC47-F37B872B0F25  Junior Ranger Program
# 22  B204DE60-5A24-43DD-8902-C81625A09A74         Living History
# 23  C8F98B28-3C10-41AE-AA99-092B3B398C43        Museum Exhibits
# 24  4D224BCA-C127-408B-AC75-A51563C42411               Paddling
# 25  0C0D142F-06B5-4BE1-8B44-491B90F93DEB              Park Film
# 26  7779241F-A70B-49BC-86F0-829AE332C708             Playground
# 27  42CF4021-8524-428E-866A-D33097A4A764           SCUBA Diving
# 28  24380E3F-AD9D-4E38-BF13-C8EEB21893E7               Shopping
# 29  F9B1D433-6B86-4804-AED7-B50A519A3B7C                 Skiing
# 30  3EBF7EAC-68FC-4754-B6A4-0C38A1583D45             Snorkeling
# 31  C38B3C62-1BBF-4EA1-A1A2-35DE21B74C17              Snow Play
# 32  7C912B83-1B1B-4807-9B66-97C12211E48E           Snowmobiling
# 33  01D717BC-18BB-4FE4-95BA-6B13AD702038            Snowshoeing
# 34  AE3C95F5-E05B-4A28-81DD-1C5FD4BE88E2                Surfing
# 35  587BB2D3-EC35-41B2-B3F7-A39E2B088AEE               Swimming
# 36  94369BFD-F186-477E-8713-AE2A745154DA            Team Sports
# 37  4D06CEED-90C6-4B69-B264-32CC90B69BA6                 Tubing
# 38  8A1C7B17-C2C6-4F7C-9539-EA1E19971D80           Water Skiing
# 39  0B685688-3405-4E2A-ABBA-E3069492EC50      Wildlife Watching

# %%
# Function to transform parks data by activities into a DataFrame
def transform_parks_to_df(data):
    parks_list = []
    for activity in data['data']:
        for park in activity['parks']:
            parks_list.append({
                'activity_id': activity['id'],
                'activity_name': activity['name'],
                'designation': park.get('designation', ''),
                'fullName': park['fullName'],
                'name': park['name'],
                'parkCode': park['parkCode'],
                'states': park['states'],
                'url': park['url']
            })
    parks_df = pd.DataFrame(parks_list)
    return parks_df

# Transform parks data by activities into a DataFrame
parks_df = transform_parks_to_df(activities_park_data)

parks_df
# Out:
#                                activity_id      activity_name  \
# 0     09DF0950-D319-4557-A57E-04CD2F63FF42   Arts and Culture
# 1     09DF0950-D319-4557-A57E-04CD2F63FF42   Arts and Culture
# 2     09DF0950-D319-4557-A57E-04CD2F63FF42   Arts and Culture
# 3     09DF0950-D319-4557-A57E-04CD2F63FF42   Arts and Culture
# 4     09DF0950-D319-4557-A57E-04CD2F63FF42   Arts and Culture
# ...                                    ...                ...
# 4008  0B685688-3405-4E2A-ABBA-E3069492EC50  Wildlife Watching
# 4009  0B685688-3405-4E2A-ABBA-E3069492EC50  Wildlife Watching
# 4010  0B685688-3405-4E2A-ABBA-E3069492EC50  Wildlife Watching
# 4011  0B685688-3405-4E2A-ABBA-E3069492EC50  Wildlife Watching
# 4012  0B685688-3405-4E2A-ABBA-E3069492EC50  Wildlife Watching
#
#                                     designation  \
# 0                                 National Park
# 1                             National Monument
# 2                             National Monument
# 3                             National Monument
# 4                       National Historic Trail
# ...                                         ...
# 4008                              National Park
# 4009  Part of Colonial National Historical Park
# 4010                              National Park
# 4011                          National Preserve
# 4012                              National Park
#
#                                                fullName  \
# 0                                  Acadia National Park
# 1               African Burial Ground National Monument
# 2                   Agate Fossil Beds National Monument
# 3             Alibates Flint Quarries National Monument
# 4                   Ala Kahakai National Historic Trail
# ...                                                 ...
# 4008                          Yellowstone National Park
# 4009  Yorktown Battlefield Part of Colonial National...
# 4010                             Yosemite National Park
# 4011           Yukon - Charley Rivers National Preserve
# 4012                                 Zion National Park
#
#                          name parkCode    states  \
# 0                      Acadia     acad        ME
# 1       African Burial Ground     afbg        NY
# 2           Agate Fossil Beds     agfo        NE
# 3     Alibates Flint Quarries     alfl        TX
# 4                 Ala Kahakai     alka        HI
# ...                       ...      ...       ...
# 4008              Yellowstone     yell  ID,MT,WY
# 4009     Yorktown Battlefield     york        VA
# 4010                 Yosemite     yose        CA
# 4011   Yukon - Charley Rivers     yuch        AK
# 4012                     Zion     zion        UT
#
#                                      url
# 0     https://www.nps.gov/acad/index.htm
# 1     https://www.nps.gov/afbg/index.htm
# 2     https://www.nps.gov/agfo/index.htm
# 3     https://www.nps.gov/alfl/index.htm
# 4     https://www.nps.gov/alka/index.htm
# ...                                  ...
# 4008  https://www.nps.gov/yell/index.htm
# 4009  https://www.nps.gov/york/index.htm
# 4010  https://www.nps.gov/yose/index.htm
# 4011  https://www.nps.gov/yuch/index.htm
# 4012  https://www.nps.gov/zion/index.htm
#
# [4013 rows x 8 columns]

# %%
# Filter out parks that do not have the designation "National Park"
activities_by_parks_df = parks_df[parks_df['designation'] == 'National Park']

# Pretty-print the filtered parks DataFrame
print("Filtered Parks DataFrame:")
activities_by_parks_df.head()
# Out:
# Filtered Parks DataFrame:
#                              activity_id     activity_name    designation  \
# 0   09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 9   09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 26  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 34  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
# 54  09DF0950-D319-4557-A57E-04CD2F63FF42  Arts and Culture  National Park
#
#                          fullName             name parkCode states  \
# 0            Acadia National Park           Acadia     acad     ME
# 9            Arches National Park           Arches     arch     UT
# 26     Capitol Reef National Park     Capitol Reef     care     UT
# 34  Cuyahoga Valley National Park  Cuyahoga Valley     cuva     OH
# 54          Glacier National Park          Glacier     glac     MT
#
#                                    url
# 0   https://www.nps.gov/acad/index.htm
# 9   https://www.nps.gov/arch/index.htm
# 26  https://www.nps.gov/care/index.htm
# 34  https://www.nps.gov/cuva/index.htm
# 54  https://www.nps.gov/glac/index.htm

# %%
# Save transformed activities DataFrame to a JSON file
activities_df.to_json('activities.json', orient='records', indent=4)

# Save transformed activities DataFrame to a CSV file
activities_df.to_csv('activities.csv', index=False)
print("DataFrame exported to activities.csv")

# Save filtered parks DataFrame to a JSON file
activities_by_parks_df.to_json('activities_parks.json', orient='records', indent=4)

# Save filtered parks DataFrame to a CSV file
activities_by_parks_df.to_csv('activities_parks.csv', index=False)
print("DataFrame exported to activities_parks.csv")
# Out:
# DataFrame exported to activities.csv
# DataFrame exported to activities_parks.csv

# %%
# NPS API endpoint for feespasses
NPS_FEES_PASSES_URL = 'https://developer.nps.gov/api/v1/feespasses'

# Build query URL
feespasses_query_url = f"{NPS_FEES_PASSES_URL}?api_key={NPS_API_KEY}"

# Fetch NPS feespasses data
feespasses_response = requests.get(feespasses_query_url)
feespasses_data = feespasses_response.json()

# Pretty-print the response
print("Fees and Passes Data:")
pprint(feespasses_data)
# Out:
# Fees and Passes Data:
# {'data': [{'cashless': 'No',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': 'Abraham Lincoln Birthplace National '
#                                      'Historical Park is free, and has no '
#                                      'associated fees.',
#            'entrancePassDescription': 'Abraham Lincoln Birthplace National '
#                                       'Historical Park is free, and does not '
#                                       'require an entrance pass.',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'abli',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': 'Depends on Location',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 3,
#                                     'timedEntry': 2},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': 'A park entrance pass is required '
#                                      'year-round at Acadia National Park. All '
#                                      'vehicles must display a pass clearly '
#                                      'visible through the windshield. Display '
#                                      'federal lands passes, such as annual and '
#                                      'military passes, on your dashboard with '
#                                      'the signature and expiration date facing '
#                                      'up. Passes are non-transferable and '
#                                      'passholder must be present. A separate '
#                                      'vehicle reservation is also required to '
#                                      'drive Cadillac Summit Road from mid-May '
#                                      'into October. Vehicle reservations are '
#                                      'only sold online in advance and are not '
#                                      'available for purchase at the park. In '
#                                      'addition to NPS locations in visitor '
#                                      'centers and campgrounds, entrance passes '
#                                      'are also available for purchase '
#                                      'in-person at third-party sellers. These '
#                                      'locations are not operated by the NPS '
#                                      'and do not offer federal lands passes -- '
#                                      '* Jordan Pond Gift Shop * Acadia '
#                                      'Regional Chamber of Commerce at Thompson '
#                                      'Island * Bar Harbor Chamber of Commerce, '
#                                      'Cottage Street * Ellsworth Chamber of '
#                                      'Commerce * Mount Desert Chamber of '
#                                      'Commerce * Southwest Harbor/Tremont '
#                                      'Chamber of Commerce',
#            'entrancePassDescription': 'A park entrance pass is required '
#                                       'year-round. All vehicles must display a '
#                                       'pass clearly visible through the '
#                                       'windshield. Display federal lands '
#                                       'passes, such as annual and military '
#                                       'passes, on your dashboard with the '
#                                       'signature and expiration date facing '
#                                       'up. Passes are non-transferable and '
#                                       'passholder must be present.',
#            'fees': [{'cost': '6.00',
#                      'description': 'Vehicle reservations are not required for '
#                                     'any other areas of the park, or for '
#                                     'visitors who enter the area by foot, '
#                                     'bike, or taxi. Vehicle reservations '
#                                     'provide a timed entry, but do not require '
#                                     'a departure time until 9 pm, when the '
#                                     'road closes to vehicles. Reservations do '
#                                     'not permit re-entry. Reservations are per '
#                                     'vehicle, not per person. Reservations do '
#                                     'not assign a specific parking space. '
#                                     'Parking is prohibited outside of '
#                                     'designated spaces. Cadillac is not served '
#                                     'by the Island Explorer bus system.',
#                      'endDate': {'day': 27, 'holiday': None, 'month': 10},
#                      'entranceFeeType': 'Timed Entry Reservation - Location',
#                      'exceptions': '',
#                      'id': 'B0ACE361-8899-4098-A238-18BA39FD67C2',
#                      'informationUrl': 'https://www.nps.gov/acad/planyourvisit/vehicle_reservations.htm',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': 'Vehicle reservations cost $6. They '
#                                            'are only sold online in advance at '
#                                            'Recreation.gov. They are not '
#                                            'available for purchase at the '
#                                            'park. In addition to purchasing a '
#                                            'vehicle reservation for Cadillac '
#                                            'Summit Road, vehicles must display '
#                                            'a park entrance pass through the '
#                                            'windshield. Park entrance passes '
#                                            'are available at the park or '
#                                            'online at Recreation.gov. Print or '
#                                            'save a digital copy of the QR Code '
#                                            'that comes with the vehicle '
#                                            'reservation confirmation email. It '
#                                            'will be scanned to verify the '
#                                            'reservation.',
#                      'recGovPurchaseUrl': 'https://www.recreation.gov/timed-entry/400000',
#                      'startDate': {'day': 22, 'holiday': None, 'month': 5},
#                      'timedEntryLocation': 'Cadillac Summit Road Vehicle '
#                                            'Reservations',
#                      'timedEntryShortDescription': 'Required to drive Cadillac '
#                                                    'Summit Road'},
#                     {'cost': '35.00',
#                      'description': 'Valid for seven days. Admits private, '
#                                     'non-commercial vehicle (15 passenger '
#                                     'capacity or less) and all occupants. This '
#                                     'includes rental cars, RVs, and vans with '
#                                     'fewer than 16 passengers. If the vehicle '
#                                     'pass is purchased, no other pass is '
#                                     'necessary.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Entrance - Private Vehicle',
#                      'exceptions': '',
#                      'id': '94E30640-D3B6-40D4-9949-07C63CFE636C',
#                      'informationUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                      'npsGovPurchaseUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': 'Credit/debit card preferred.\n'
#                                            '\n'
#                                            'Three types of weekly passes '
#                                            '(Vehicle, Motorcycle, Individual) '
#                                            'may be purchased by credit card '
#                                            'from automated fee machines '
#                                            'available year-round 24 hours a '
#                                            'day --\n'
#                                            '* One is located at a pavilion in '
#                                            'the parking lot the Hulls Cove '
#                                            'Visitor Center.\n'
#                                            '* Another is available inside a '
#                                            'gatehouse at the entrance to the '
#                                            'Schoodic Institute on the Schoodic '
#                                            'Peninsula.',
#                      'recGovPurchaseUrl': 'https://www.recreation.gov/sitepass/74271',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '30.00',
#                      'description': 'Valid for seven days. Admits one or two '
#                                     'passengers on a private, non-commercial '
#                                     'motorcycle.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Entrance - Motorcycle',
#                      'exceptions': '',
#                      'id': 'A6D7D0BD-5064-4018-ACA6-471AAC4B8301',
#                      'informationUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                      'npsGovPurchaseUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': 'Credit/debit card preferred.\n'
#                                            '\n'
#                                            'Three types of weekly passes '
#                                            '(Vehicle, Motorcycle, Individual) '
#                                            'may be purchased by credit card '
#                                            'from automated fee machines '
#                                            'available year-round 24 hours a '
#                                            'day --\n'
#                                            '* One is located at a pavilion in '
#                                            'the parking lot the Hulls Cove '
#                                            'Visitor Center.\n'
#                                            '* Another is available inside a '
#                                            'gatehouse at the entrance to the '
#                                            'Schoodic Institute on the Schoodic '
#                                            'Peninsula.',
#                      'recGovPurchaseUrl': 'https://www.recreation.gov/sitepass/74271',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '20.00',
#                      'description': 'Valid for seven days. Admits one '
#                                     'individual with no car (bicyclist, hiker, '
#                                     'pedestrian). Youth 15 and under are '
#                                     'admitted free of charge.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Entrance - Per Person',
#                      'exceptions': '',
#                      'id': 'CE8B4FBB-3410-49D1-97DF-B4F019CDD058',
#                      'informationUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                      'npsGovPurchaseUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': 'Credit/debit card preferred.\n'
#                                            '\n'
#                                            'Three types of weekly passes '
#                                            '(Vehicle, Motorcycle, Individual) '
#                                            'may be purchased by credit card '
#                                            'from automated fee machines '
#                                            'available year-round 24 hours a '
#                                            'day --\n'
#                                            '* One is located at a pavilion in '
#                                            'the parking lot the Hulls Cove '
#                                            'Visitor Center.\n'
#                                            '* Another is available inside a '
#                                            'gatehouse at the entrance to the '
#                                            'Schoodic Institute on the Schoodic '
#                                            'Peninsula.',
#                      'recGovPurchaseUrl': 'https://www.recreation.gov/sitepass/74271',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '0.00',
#                      'description': 'School groups and other academic '
#                                     'institutions may qualify for an '
#                                     'Educational Fee Waiver. If not qualified, '
#                                     'please check fees for large or commercial '
#                                     'groups.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Entrance - Education/Academic Groups',
#                      'exceptions': '',
#                      'id': 'BBA5FD20-F7E2-4185-84E9-CECEAB42C43B',
#                      'informationUrl': 'https://www.nps.gov/acad/planyourvisit/feewaivers.htm',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '0.00',
#                      'description': 'Groups entering Acadia by bus, van, or '
#                                     'other high-capacity vehicles (16 people '
#                                     'or more) must pay an organized group '
#                                     'entrance fee.\n'
#                                     '\n'
#                                     'Adults (16 years old and over): $20/per '
#                                     'person\n'
#                                     'Youth (15 years old and under): Free',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Entrance - Non-commercial Groups',
#                      'exceptions': '',
#                      'id': '8B5FB8A4-46C0-43A1-BCEF-3D8D35E1A89F',
#                      'informationUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '0.00',
#                      'description': 'Are you operating a business that '
#                                     'provides leisure or recreational services '
#                                     'while in the park? If so, it is '
#                                     'considered a commercial group and you are '
#                                     'required to have a Commercial Use '
#                                     'Authorization.\n'
#                                     '\n'
#                                     'A commercial group is defined as '
#                                     'consisting of one or more persons '
#                                     'traveling on an itinerary that has been '
#                                     'packaged, priced, or sold for leisure or '
#                                     'recreational purposes by an organization '
#                                     'that realizes financial gain through the '
#                                     'provisions of the service. Learn more on '
#                                     'our "Do Business With Us" page.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Commercial Entrance - Per Person',
#                      'exceptions': '',
#                      'id': '46D75731-D4BF-45DE-88FC-54C93ADBB9AB',
#                      'informationUrl': 'https://www.nps.gov/acad/getinvolved/dobusinesswithus.htm',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''}],
#            'feesAtWorkUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#            'isFeeFreePark': False,
#            'isInteragencyPassAccepted': True,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'acad',
#            'parkingDetailsUrl': '',
#            'passes': [{'category': 'Annual Entrance - Park',
#                        'cost': '70.00',
#                        'description': 'The Acadia Annual Pass is valid only at '
#                                       'Acadia and may be purchased online or '
#                                       'in person. You do not need an '
#                                       'additional entrance pass if you already '
#                                       'have a federal lands pass. It is valid '
#                                       'for 12 months from purchase month. This '
#                                       'pass admits the pass holder and '
#                                       'passengers in a non-commercial '
#                                       'vehicle.\n'
#                                       '\n'
#                                       'In addition to park visitor centers and '
#                                       'campgrounds, the Acadia Annual Pass is '
#                                       'available at the Acadia Regional '
#                                       'Chamber at Thompson Island, and at Bar '
#                                       'Harbor, Ellsworth and Southwest Harbor '
#                                       'chambers of commerce.',
#                        'exceptions': '',
#                        'id': 'F647C604-6000-4454-A9FB-6147436E8A7C',
#                        'image': [{'altText': 'Landscape photo of a grove of '
#                                              'birch trees with white bark and '
#                                              'yellow leaves in autumn',
#                                   'caption': '2024 Acadia Annual Pass',
#                                   'credit': 'Photo courtesy of visitor Gordon '
#                                             'Grisinger',
#                                   'title': '2024 Acadia Annual Pass',
#                                   'url': 'https://www.nps.gov/common/uploads/entrance_pass/A2EFE238-B681-6332-7574A8F7F96AB4E9.jpg'}],
#                        'informationUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                        'npsGovPurchaseUrl': 'https://www.nps.gov/acad/planyourvisit/fees.htm',
#                        'payGovPurchaseUrl': '',
#                        'paymentDescription': '',
#                        'recGovPurchaseUrl': 'https://www.recreation.gov/sitepass/74271'}],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': 'Vehicle reservations are not required for '
#                                     'any other areas of the park, or for '
#                                     'visitors who enter the area by foot, '
#                                     'bike, or taxi. Vehicle reservations '
#                                     'provide a timed entry, but do not require '
#                                     'a departure time until 9 pm, when the '
#                                     'road closes to vehicles. Reservations do '
#                                     'not permit re-entry. Reservations are per '
#                                     'vehicle, not per person. Reservations do '
#                                     'not assign a specific parking space. '
#                                     'Parking is prohibited outside of '
#                                     'designated spaces. Cadillac is not served '
#                                     'by the Island Explorer bus system.',
#            'timedEntryHeading': 'Cadillac Summit Road Vehicle Reservations '
#                                 'Reservation'},
#           {'cashless': 'Yes',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 3,
#                                     'timedEntry': 2},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': 'Entrance into the historic homes at '
#                                      'Adams National Historical Park requires '
#                                      'an entrance pass. Entrance passes cost '
#                                      '$15 per person. Children under the age '
#                                      'of 16 are free. If you have an America '
#                                      'the Beautiful Interagency Pass, you do '
#                                      'not need to pay the entrance fee. Tours '
#                                      'can be reserved online in advance at '
#                                      'recreation.gov or in-person on the day '
#                                      'of your visit at the park’s visitor '
#                                      'center. Tour reservations are required '
#                                      'in addition to entrance passes.',
#            'entrancePassDescription': 'Adams National Historical Park has a '
#                                       'digital annual pass available for '
#                                       'purchase on Recreation.gov. This pass '
#                                       'is good for 12 months following the '
#                                       'purchase of the pass. Tickets are still '
#                                       'required to enter the park, but the '
#                                       'digital annual pass will ensure the '
#                                       'passholder free entry into the park. '
#                                       'The pass costs $45.',
#            'fees': [{'cost': '1.00',
#                      'description': 'The park offers tours of the historic '
#                                     'homes. A reservation is required to '
#                                     'attend a guided tour. It is strongly '
#                                     'recommended to make reservations in '
#                                     'advance on Adams National Historical '
#                                     "Park's Recreation.gov page. A limited "
#                                     'number of reservations will be available '
#                                     'day-of for free on a first-come, '
#                                     'first-served basis at the Visitor Center.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 10},
#                      'entranceFeeType': 'Timed Entry Reservation - Location',
#                      'exceptions': '',
#                      'id': '3731EBA3-EF53-403B-8C27-F02EBA8D5CEB',
#                      'informationUrl': 'https://www.recreation.gov/ticket/facility/300003',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': 'https://www.recreation.gov/ticket/facility/300003',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 5},
#                      'timedEntryLocation': 'Advanced Tour',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '15.00',
#                      'description': 'Entrance into the historic homes at Adams '
#                                     'National Historical Park requires an '
#                                     'entrance pass. Entrance passes cost $15 '
#                                     'per person. Children under the age of 16 '
#                                     'are free. If you have an America the '
#                                     'Beautiful Interagency Pass, you do not '
#                                     'need to pay the entrance fee. Tours can '
#                                     'be reserved online in advance at '
#                                     'recreation.gov or in-person on the day of '
#                                     'your visit at the park’s visitor center. '
#                                     'Tour reservations are required in '
#                                     'addition to entrance passes.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 10},
#                      'entranceFeeType': 'Entrance - Per Person',
#                      'exceptions': '',
#                      'id': 'E08949D2-8971-43EF-B9F1-27CB13016466',
#                      'informationUrl': '',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 5},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''}],
#            'feesAtWorkUrl': 'https://www.nps.gov/adam/learn/management/yourdollarsatwork.htm',
#            'isFeeFreePark': False,
#            'isInteragencyPassAccepted': True,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'adam',
#            'parkingDetailsUrl': '',
#            'passes': [{'category': 'Annual Entrance - Park',
#                        'cost': '45.00',
#                        'description': 'Adams National Historical Park has a '
#                                       'digital annual pass available for '
#                                       'purchase on Recreation.gov.  This pass '
#                                       'is good for 12 months following the '
#                                       'purchase of the pass.  Tickets are '
#                                       'still required to enter the park, but '
#                                       'the digital annual pass will ensure the '
#                                       'passholder free entry into the park.  '
#                                       'The pass costs $45.',
#                        'exceptions': '',
#                        'id': 'DF9A61D1-3D4D-4C16-BDA4-6CEEBCDCD50C',
#                        'image': [{'altText': 'A gray, stone pathway, leads to '
#                                              'the Stone Library and Old House',
#                                   'caption': 'A gray, stone pathway, leads to '
#                                              'the Stone Library and Old House',
#                                   'credit': 'NPS Photo',
#                                   'title': 'Old House and Peace Field Garden',
#                                   'url': 'https://www.nps.gov/common/uploads/entrance_pass/8483234E-CF96-868E-214766695ABBE23A.jpg'}],
#                        'informationUrl': '',
#                        'npsGovPurchaseUrl': '',
#                        'payGovPurchaseUrl': '',
#                        'paymentDescription': '',
#                        'recGovPurchaseUrl': ''}],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': 'Depends on Location',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': True,
#            'isParkingOrTransportationFeePossible': True,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'afam',
#            'parkingDetailsUrl': 'https://www.nps.gov/nama/planyourvisit/parking.htm',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'afbg',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'agfo',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'alag',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': 'No',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 2,
#                                     'timedEntry': 3},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': 'Visiting Alcatraz Island is one of the '
#                                      'most rewarding experiences of any trip '
#                                      'to San Francisco. However, visitors who '
#                                      'wish to visit the prison and island '
#                                      'grounds must secure reservations. For '
#                                      'over a decade, the National Park Service '
#                                      'has implemented a reservation system, '
#                                      'which is much different from the ways '
#                                      'past generations accessed the Alcatraz '
#                                      'Island. The National Park Service '
#                                      'strongly recommends making advanced '
#                                      'ticket reservations. Reservations '
#                                      'secured far enough in advance allow '
#                                      'visitors to visit and also eliminate the '
#                                      'need to wait in line to purchase '
#                                      'tickets. Alcatraz tickets are all '
#                                      'inclusive. The ticket price includes the '
#                                      'ferry transportation service provided by '
#                                      'Alcatraz City Cruises, the cellhouse '
#                                      'audio tour provided by the Golden Gate '
#                                      'National Parks Conservancy, and the '
#                                      'Federal Lands Recreation Enhancement Act '
#                                      'fee. For additional information on '
#                                      'schedules, prices, and to purchase '
#                                      'tickets in advance (tickets are made '
#                                      'available about 90 days in advance) '
#                                      'please visit the Alcatraz City Cruises.',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': True,
#            'isParkingOrTransportationFeePossible': True,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'alca',
#            'parkingDetailsUrl': 'https://www.alcatrazcitycruises.com',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': 'This unit is on private land owned by '
#                                      'the Ounalashka Corporation. To visit the '
#                                      'historic area, you need to purchase a '
#                                      'permit. Visitors can purchase these '
#                                      'permits by calling the corporation at '
#                                      '(907) 581-1276, or by visiting the '
#                                      'corporation Monday - Friday at 400 '
#                                      'Salmon Way. Permits can also be '
#                                      'purchased at the visitor center. The '
#                                      'cost for a permit is as follows: Type of '
#                                      'permit Daily $6 (individual) $10 '
#                                      '(family) Weekly $15 (individual) $20 '
#                                      '(family) Annual $60 (individual) $80 '
#                                      '(family) Visitor passes for the World '
#                                      'War II Visitor Center are free to '
#                                      'veterans, $2 for active military and '
#                                      'seniors over age 55 and $5 for all '
#                                      'others.',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'aleu',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': 'No',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'alfl',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': False,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'alka',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'alpo',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'amch',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': 'Yes',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 3,
#                                     'timedEntry': 2},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': 'Amistad National Recreation Area does '
#                                       'not charge entrance fees. However, the '
#                                       'park does sell the America the '
#                                       'Beautiful - The National Parks and '
#                                       'Federal Recreational Lands Pass Series '
#                                       'for federal public lands managed by the '
#                                       'National Park Service, Forest Service, '
#                                       'Bureau of Land Management, U.S. Army '
#                                       'Corps of Engineers, Bureau of '
#                                       'Reclamation, and U.S. Fish & Wildlife '
#                                       'Service.',
#            'fees': [],
#            'feesAtWorkUrl': 'https://www.nps.gov/amis/learn/management/yourdollarsatwork.htm',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': True,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'amis',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': 'Yes',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'amme',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'anac',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': True,
#            'isParkingOrTransportationFeePossible': True,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'anch',
# ...
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '40.00',
#                      'description': 'Commercial tour fee for vehicle/bus with '
#                                     'seating capacity of 7-25.  Fee is $40.00 '
#                                     'per vehicle.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Commercial Entrance - Van',
#                      'exceptions': '',
#                      'id': '575CBC6F-8A92-4E5C-A8DE-2DA7D1E00C96',
#                      'informationUrl': '',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '40.00',
#                      'description': 'Commercial tour fee for vehicle/bus with '
#                                     'seating capacity of 7-25.  Fee is $40.00 '
#                                     'per vehicle.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Commercial Entrance - Mini-bus',
#                      'exceptions': '',
#                      'id': '2BDC24E2-FD2F-4B30-AB7E-B816F8F703A7',
#                      'informationUrl': '',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '100.00',
#                      'description': 'Commercial tour fee for vehicle/bus with '
#                                     'seating capacity of 26 or more.  Fee is '
#                                     '$100.00 per vehicle.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Commercial Entrance - Motor Coach',
#                      'exceptions': '',
#                      'id': 'F87760B8-D501-4035-832D-5C6D2946D482',
#                      'informationUrl': '',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '30.00',
#                      'description': 'Non-commercial vehicles with a vehicle '
#                                     'capacity of 15 or fewer: $30.00 per '
#                                     'vehicle, regardless of the number of '
#                                     'passengers.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Entrance - Non-commercial Groups',
#                      'exceptions': '',
#                      'id': '2F7C9123-F92E-433C-B253-C3390F8330E8',
#                      'informationUrl': '',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''},
#                     {'cost': '15.00',
#                      'description': 'Non-commercial vehicles with a vehicle '
#                                     'capacity of 16 or greater: $15.00 per '
#                                     'passenger (including driver). Fees will '
#                                     'not exceed the commercial fee for the '
#                                     'same-sized vehicle. Youth 15 and under '
#                                     'are free. Individuals or families with '
#                                     'any valid Annual or Lifetime pass may use '
#                                     'their pass for entry at the per-person '
#                                     'rate. Pass and photo ID must be presented '
#                                     'upon entry.',
#                      'endDate': {'day': 31, 'holiday': None, 'month': 12},
#                      'entranceFeeType': 'Entrance - Non-commercial Groups',
#                      'exceptions': '',
#                      'id': '1BF05EC1-6338-498E-AB65-8C5AC2C1BF4B',
#                      'informationUrl': '',
#                      'npsGovPurchaseUrl': '',
#                      'payGovPurchaseUrl': '',
#                      'paymentDescription': '',
#                      'recGovPurchaseUrl': '',
#                      'startDate': {'day': 1, 'holiday': None, 'month': 1},
#                      'timedEntryLocation': '',
#                      'timedEntryShortDescription': ''}],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': False,
#            'isInteragencyPassAccepted': True,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'blca',
#            'parkingDetailsUrl': '',
#            'passes': [{'category': 'Annual Entrance - Park',
#                        'cost': '55.00',
#                        'description': 'An annual pass to Black Canyon of the '
#                                       'Gunnison National Park is available for '
#                                       '$55.00 at the South Rim entrance '
#                                       'station from early April to late '
#                                       'October, and at Recreation.gov. This '
#                                       'pass admits the permit holder and all '
#                                       'accompanying passengers in a single, '
#                                       'private, noncommercial vehicle to the '
#                                       'park. It is valid for 12 months from '
#                                       'date of purchase and covers entrance '
#                                       'fees only.',
#                        'exceptions': '',
#                        'id': 'BE12F089-EDAF-4E5F-98FF-7F559D8CBA0A',
#                        'image': [{'altText': 'An image of Black Canyon with '
#                                              'the sun setting over the canyon '
#                                              'rim',
#                                   'caption': 'The Black Canyon Annual Pass '
#                                              'allows entrance into Black '
#                                              'Canyon of the Gunnison National '
#                                              'Park for 12 months from the time '
#                                              'of purchase.',
#                                   'credit': 'NPS Photo',
#                                   'title': 'Black Canyon of the Gunnison '
#                                            'Annual Pass',
#                                   'url': 'https://www.nps.gov/common/uploads/entrance_pass/E60A557C-A038-6A89-F69151F6D594D1C0.png'}],
#                        'informationUrl': '',
#                        'npsGovPurchaseUrl': '',
#                        'payGovPurchaseUrl': '',
#                        'paymentDescription': '',
#                        'recGovPurchaseUrl': 'https://www.recreation.gov/sitepass/74332'}],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': 'Yes',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': 'No fee is charged to travel the Blue '
#                                      'Ridge Parkway. There is a charge for '
#                                      'camping in any of the campgrounds along '
#                                      'the parkway. Visitors with the Senior '
#                                      'Pass or Access Pass (formerly Golden Age '
#                                      'or Golden Access Passports) pay a '
#                                      'reduced camping fee. Some activities on '
#                                      'the parkway require a permit, such as '
#                                      'weddings, commercial tour groups or '
#                                      'filming, agricultural leases, scientific '
#                                      'research, and right of way access. '
#                                      'Please go to our permits page for '
#                                      'additional information. All National '
#                                      'Parks & Federal Recreational Lands '
#                                      'Passes are available at campground '
#                                      'kiosks on the Parkway, during their '
#                                      'operating season, typically from the end '
#                                      'of May through October. During the '
#                                      "Parkway's off-season (typically November "
#                                      'through the end of May) passes can be '
#                                      'ordered online through the US Geological '
#                                      'Survey. For information visit '
#                                      'Recreational Passes | USGS Store or call '
#                                      '1-888-275-8747.',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': 'https://www.nps.gov/blri/planyourvisit/fees.htm',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': True,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'blri',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': 'No',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'blrv',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'blsc',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'blue',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'boaf',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''},
#           {'cashless': '',
#            'contentOrderOrdinals': {'customFee': 4,
#                                     'entranceFee': 1,
#                                     'paidParking': 1,
#                                     'timedEntry': 1},
#            'customFeeDescription': '',
#            'customFeeHeading': '',
#            'customFeeLinkText': '',
#            'customFeeLinkUrl': '',
#            'entranceFeeDescription': '',
#            'entrancePassDescription': '',
#            'fees': [],
#            'feesAtWorkUrl': '',
#            'isFeeFreePark': True,
#            'isInteragencyPassAccepted': False,
#            'isParkingFeePossible': False,
#            'isParkingOrTransportationFeePossible': False,
#            'paidParkingDescription': '',
#            'paidParkingHeading': '',
#            'parkCode': 'boha',
#            'parkingDetailsUrl': '',
#            'passes': [],
#            'relatedMultiSitePasses': [],
#            'timedEntryDescription': '',
#            'timedEntryHeading': ''}],
#  'limit': '50',
#  'start': '0',
#  'total': '471'}

# %%
# Function to transform feespasses data into a DataFrame
def transform_feespasses_to_df(data):
    feespasses_list = []
    for item in data['data']:
        costs = [float(fee['cost']) for fee in item['fees'] if 'cost' in fee]
        passCosts = [float(fee['cost']) for fee in item['passes'] if 'cost' in fee]

        # Summarize the costs
        total_fee = sum(costs) if costs else 0
        average_fee = sum(costs) / len(costs) if costs else 0
        total_pass_cost = sum(passCosts) if passCosts else 0
        average_pass_cost = sum(passCosts) / len(passCosts) if passCosts else 0
        
        feespasses_list.append({
            'parkCode': item['parkCode'],
            'totalFees': total_fee,
            'averageFees': average_fee,
            'totalPasses': total_pass_cost,
            'averagePasses': average_pass_cost,
            'isFeeFreePark': item['isFeeFreePark'],
            'entrancePassDescription': item['entrancePassDescription'],
            'entranceFeeDescription': item['entranceFeeDescription'],
            'feesAtWorkUrl': item.get('feesAtWorkUrl', '')
        })
    feespasses_df = pd.DataFrame(feespasses_list)
    return feespasses_df

# Transform feespasses data into a DataFrame
feespasses_df = transform_feespasses_to_df(feespasses_data)
feespasses_df.head()
# Out:
#   parkCode  totalFees  averageFees  totalPasses  averagePasses  isFeeFreePark  \
# 0     abli        0.0          0.0          0.0            0.0           True
# 1     acad       91.0         13.0         70.0           70.0          False
# 2     adam       16.0          8.0         45.0           45.0          False
# 3     afam        0.0          0.0          0.0            0.0           True
# 4     afbg        0.0          0.0          0.0            0.0           True
#
#                              entrancePassDescription  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1  A park entrance pass is required year-round. A...
# 2  Adams National Historical Park has a digital a...
# 3
# 4
#
#                               entranceFeeDescription  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1  A park entrance pass is required year-round at...
# 2  Entrance into the historic homes at Adams Nati...
# 3
# 4
#
#                                        feesAtWorkUrl
# 0
# 1    https://www.nps.gov/acad/planyourvisit/fees.htm
# 2  https://www.nps.gov/adam/learn/management/your...
# 3
# 4

# %%
# Filter the feespasses_df DataFrame to include only the park codes with the designation "National Park"
national_park_codes = activities_by_parks_df['parkCode'].unique()
filtered_feespasses_df = feespasses_df[feespasses_df['parkCode'].isin(national_park_codes)]

# Pretty-print the transformed and filtered feespasses DataFrame
print("Filtered FeesPasses DataFrame for National Parks:")
filtered_feespasses_df.head()
# Out:
# Filtered FeesPasses DataFrame for National Parks:
#    parkCode  totalFees  averageFees  totalPasses  averagePasses  \
# 1      acad       91.0    13.000000         70.0           70.0
# 24     arch       72.0    18.000000         55.0           55.0
# 29     badl      355.0    50.714286         55.0           55.0
# 35     bibe      425.0    60.714286         55.0           55.0
# 40     bisc        0.0     0.000000          0.0            0.0
#
#     isFeeFreePark                            entrancePassDescription  \
# 1           False  A park entrance pass is required year-round. A...
# 24          False
# 29          False
# 35          False  Big Bend National Park Annual Pass: $55 Covers...
# 40           True
#
#                                entranceFeeDescription  \
# 1   A park entrance pass is required year-round at...
# 24
# 29  Badlands National Park charges an entrance fee...
# 35  All vehicles entering Big Bend National Park a...
# 40
#
#                                         feesAtWorkUrl
# 1     https://www.nps.gov/acad/planyourvisit/fees.htm
# 24  https://www.nps.gov/arch/learn/management/your...
# 29
# 35  https://www.nps.gov/bibe/learn/management/your...
# 40

# %%
# Save transformed and filtered feespasses DataFrame to a JSON file
filtered_feespasses_df.to_json('feespasses.json', orient='records', indent=4)

# Save transformed and filtered feespasses DataFrame to a CSV file
filtered_feespasses_df.to_csv('feespasses.csv', index=False)
print("DataFrame exported to feespasses.csv")
# Out:
# DataFrame exported to feespasses.csv

# %%
import os
import shutil

# Define the folder name
folder_name = 'NPS_Project_Extracted_Data'

# Create the folder if it doesn't exist
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Define the file names and paths
files = {
    'activities_parks.json': 'activities_parks.json',
    'activities.json': 'activities.json',
    'feespasses.json': 'feespasses.json', 
    'activities.csv':'activities.csv',
    'activities_parks.csv': 'activities_parks.csv',
    'feespasses.csv': 'activities.csv'
}

# Move each file into the folder
for target_name, source_path in files.items():
    if os.path.exists(source_path):
        shutil.move(source_path, os.path.join(folder_name, target_name))

# Verify the files have been moved
print(f"Files moved to {folder_name}: {os.listdir(folder_name)}")
# Out:
# Files moved to NPS_Project_Extracted_Data: []
